# %% [markdown]
# ## Vamos a importar aqui las librerías y documentos necesarios.

# %%
from Utils import credentials
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In [2], line 1
# ----> 1 from Utils import credentials
#
# ModuleNotFoundError: No module named 'Utils'

# %%
import json
import tweepy
import requests
import pandas as pd
from datetime import datetime
import sqlite3

# %% [markdown]
# #### Ingresamos las Keys y los Token y contactamos con la API.

# %%
auth=tweepy.OAuthHandler(credentials.API_KEY,credentials.API_SECRET_KEY)
auth.set_access_token(credentials.ACCESS_TOKEN,credentials.ACCESS_TOKEN_SECRET)

api=tweepy.API(auth)

# %%
#lista_mensajes={}
for message in tweepy.Cursor(api.search_full_archive,'development','@TheBridge_Tech').items(150):
#        lista_mensajes.append(message)
        print(json.dumps (message._json, indent=2))
# Out:
# {
#   "created_at": "Sat Oct 08 05:07:45 +0000 2022",
#   "id": 1578613094191796224,
#   "id_str": "1578613094191796224",
#   "text": "Gente muy agradable en @TheBridge_Tech , te ries mucho en el dia a dia. El tema es que pasas tanto tiempo trabajand\u2026 https://t.co/mRdVPEb9b2",
#   "source": "<a href=\"https://mobile.twitter.com\" rel=\"nofollow\">Twitter Web App</a>",
#   "truncated": true,
#   "in_reply_to_status_id": null,
#   "in_reply_to_status_id_str": null,
#   "in_reply_to_user_id": null,
#   "in_reply_to_user_id_str": null,
#   "in_reply_to_screen_name": null,
#   "user": {
#     "id": 1578095844569514011,
#     "id_str": "1578095844569514011",
#     "name": "Rocket",
#     "screen_name": "75_Rocket_",
#     "location": null,
#     "url": null,
#     "description": null,
#     "translator_type": "none",
#     "protected": false,
#     "verified": false,
#     "followers_count": 0,
#     "friends_count": 2,
#     "listed_count": 0,
#     "favourites_count": 0,
#     "statuses_count": 1,
#     "created_at": "Thu Oct 06 18:52:48 +0000 2022",
#     "utc_offset": null,
#     "time_zone": null,
#     "geo_enabled": false,
#     "lang": null,
#     "contributors_enabled": false,
#     "is_translator": false,
#     "profile_background_color": "F5F8FA",
#     "profile_background_image_url": "",
#     "profile_background_image_url_https": "",
#     "profile_background_tile": false,
#     "profile_link_color": "1DA1F2",
#     "profile_sidebar_border_color": "C0DEED",
#     "profile_sidebar_fill_color": "DDEEF6",
#     "profile_text_color": "333333",
#     "profile_use_background_image": true,
#     "profile_image_url": "http://pbs.twimg.com/profile_images/1578611659366612992/bSWyxp1D_normal.jpg",
#     "profile_image_url_https": "https://pbs.twimg.com/profile_images/1578611659366612992/bSWyxp1D_normal.jpg",
#     "default_profile": true,
#     "default_profile_image": false,
#     "following": null,
#     "follow_request_sent": null,
#     "notifications": null,
#     "withheld_in_countries": []
#   },
#   "geo": null,
#   "coordinates": null,
#   "place": null,
#   "contributors": null,
#   "is_quote_status": false,
#   "extended_tweet": {
#     "full_text": "Gente muy agradable en @TheBridge_Tech , te ries mucho en el dia a dia. El tema es que pasas tanto tiempo trabajando aqui, que te quita la libido y tu vida sexual se va a la mierda, jjj. Tengo ganas de terminar mi Bootcamp para poder hacer una buena sesi\u00f3n de Shibari",
#     "display_text_range": [
#       0,
#       267
#     ],
#     "entities": {
#       "hashtags": [],
#       "urls": [],
#       "user_mentions": [
#         {
#           "screen_name": "TheBridge_Tech",
#           "name": "The Bridge",
#           "id": 1162694149956603904,
#           "id_str": "1162694149956603904",
#           "indices": [
#             23,
#             38
#           ]
#         }
#       ],
#       "symbols": []
#     }
#   },
#   "quote_count": 0,
#   "reply_count": 0,
#   "retweet_count": 0,
#   "favorite_count": 0,
#   "entities": {
#     "hashtags": [],
#     "urls": [
#       {
#         "url": "https://t.co/mRdVPEb9b2",
#         "expanded_url": "https://twitter.com/i/web/status/1578613094191796224",
#         "display_url": "twitter.com/i/web/status/1\u2026",
#         "indices": [
#           117,
#           140
#         ]
#       }
#     ],
#     "user_mentions": [
#       {
#         "screen_name": "TheBridge_Tech",
#         "name": "The Bridge",
#         "id": 1162694149956603904,
#         "id_str": "1162694149956603904",
#         "indices": [
#           23,
#           38
#         ]
#       }
#     ],
#     "symbols": []
#   },
#   "favorited": false,
#   "retweeted": false,
#   "edit_history": {
#     "initial_tweet_id": "1578613094191796224",
#     "edit_tweet_ids": [
#       "1578613094191796224"
#     ]
#   },
#   "edit_controls": {
#     "editable_until_ms": 1665207465000,
#     "edits_remaining": 5
#   },
#   "editable": true,
#   "filter_level": "low",
#   "lang": "es",
#   "matching_rules": [
#     {
#       "tag": null
#     }
#   ]
# }
# {
#   "created_at": "Fri Oct 07 04:51:10 +0000 2022",
#   "id": 1578246533832654848,
#   "id_str": "1578246533832654848",
#   "text": "RT @TheBridge_Tech: El pr\u00f3ximo martes 11 de octubre no te pierdas la sesi\u00f3n sobre dependencia profesional \ud83d\ude2b con la psic\u00f3loga @Mariagutim de\u2026",
#   "source": "<a href=\"http://twitter.com/download/iphone\" rel=\"nofollow\">Twitter for iPhone</a>",
#   "truncated": false,
#   "in_reply_to_status_id": null,
#   "in_reply_to_status_id_str": null,
#   "in_reply_to_user_id": null,
#   "in_reply_to_user_id_str": null,
#   "in_reply_to_screen_name": null,
#   "user": {
#     "id": 1099588676181471233,
#     "id_str": "1099588676181471233",
#     "name": "Flor_Turoninos",
#     "screen_name": "turoninos",
#     "location": "Valladolid, Espa\u00f1a",
#     "url": null,
#     "description": null,
#     "translator_type": "none",
#     "protected": false,
#     "verified": false,
#     "followers_count": 170,
#     "friends_count": 278,
#     "listed_count": 1,
#     "favourites_count": 75827,
#     "statuses_count": 6209,
#     "created_at": "Sun Feb 24 08:35:44 +0000 2019",
#     "utc_offset": null,
#     "time_zone": null,
#     "geo_enabled": true,
#     "lang": null,
#     "contributors_enabled": false,
#     "is_translator": false,
#     "profile_background_color": "F5F8FA",
#     "profile_background_image_url": "",
#     "profile_background_image_url_https": "",
#     "profile_background_tile": false,
#     "profile_link_color": "1DA1F2",
#     "profile_sidebar_border_color": "C0DEED",
#     "profile_sidebar_fill_color": "DDEEF6",
#     "profile_text_color": "333333",
#     "profile_use_background_image": true,
#     "profile_image_url": "http://pbs.twimg.com/profile_images/1099653196077809664/3PWfgS9g_normal.jpg",
#     "profile_image_url_https": "https://pbs.twimg.com/profile_images/1099653196077809664/3PWfgS9g_normal.jpg",
#     "profile_banner_url": "https://pbs.twimg.com/profile_banners/1099588676181471233/1550997765",
#     "default_profile": true,
#     "default_profile_image": false,
#     "following": null,
#     "follow_request_sent": null,
#     "notifications": null,
#     "withheld_in_countries": []
#   },
#   "geo": null,
#   "coordinates": null,
#   "place": null,
#   "contributors": null,
#   "retweeted_status": {
#     "created_at": "Thu Oct 06 12:46:17 +0000 2022",
#     "id": 1578003711154176001,
#     "id_str": "1578003711154176001",
#     "text": "El pr\u00f3ximo martes 11 de octubre no te pierdas la sesi\u00f3n sobre dependencia profesional \ud83d\ude2b con la psic\u00f3loga\u2026 https://t.co/8WD3VnJZAF",
#     "display_text_range": [
#       0,
#       140
#     ],
#     "source": "<a href=\"https://metricool.com\" rel=\"nofollow\">Metricool</a>",
#     "truncated": true,
#     "in_reply_to_status_id": null,
#     "in_reply_to_status_id_str": null,
#     "in_reply_to_user_id": null,
#     "in_reply_to_user_id_str": null,
#     "in_reply_to_screen_name": null,
#     "user": {
#       "id": 1162694149956603904,
#       "id_str": "1162694149956603904",
#       "name": "The Bridge",
#       "screen_name": "TheBridge_Tech",
#       "location": "Paseo de Recoletos, 15, Madrid",
#       "url": "https://www.thebridge.tech/",
#       "description": "Aceleradora de Talento Digital\n\nBootcamps | Corporate Skilling | University Program Management | Startup Factory",
#       "translator_type": "none",
#       "protected": false,
#       "verified": false,
#       "followers_count": 538,
#       "friends_count": 124,
#       "listed_count": 11,
#       "favourites_count": 199,
#       "statuses_count": 523,
#       "created_at": "Sat Aug 17 11:54:55 +0000 2019",
#       "utc_offset": null,
#       "time_zone": null,
#       "geo_enabled": true,
#       "lang": null,
#       "contributors_enabled": false,
#       "is_translator": false,
#       "profile_background_color": "F5F8FA",
#       "profile_background_image_url": "",
#       "profile_background_image_url_https": "",
#       "profile_background_tile": false,
#       "profile_link_color": "1DA1F2",
#       "profile_sidebar_border_color": "C0DEED",
#       "profile_sidebar_fill_color": "DDEEF6",
#       "profile_text_color": "333333",
#       "profile_use_background_image": true,
#       "profile_image_url": "http://pbs.twimg.com/profile_images/1546415533909737474/UgLpusY5_normal.jpg",
#       "profile_image_url_https": "https://pbs.twimg.com/profile_images/1546415533909737474/UgLpusY5_normal.jpg",
#       "profile_banner_url": "https://pbs.twimg.com/profile_banners/1162694149956603904/1660298543",
#       "default_profile": true,
#       "default_profile_image": false,
#       "following": null,
#       "follow_request_sent": null,
#       "notifications": null,
#       "withheld_in_countries": []
#     },
#     "geo": null,
#     "coordinates": null,
#     "place": null,
#     "contributors": null,
#     "is_quote_status": false,
#     "extended_tweet": {
#       "full_text": "El pr\u00f3ximo martes 11 de octubre no te pierdas la sesi\u00f3n sobre dependencia profesional \ud83d\ude2b con la psic\u00f3loga @Mariagutim de @Hiwook_Jobs \u00a1nos ayudar\u00e1 a entender y saber abordar este tipo de situaciones!\n\n\u23f018.30h\n\ud83e\uddd1\ud83d\udcbbOnline\n\nEntradas \ud83c\udf9f https://t.co/wu03WaxiXH\n\n#freeevents https://t.co/7X0nfl9htI",
#       "display_text_range": [
#         0,
#         265
#       ],
#       "entities": {
#         "hashtags": [
#           {
#             "text": "freeevents",
#             "indices": [
#               254,
#               265
#             ]
#           }
#         ],
#         "urls": [
#           {
#             "url": "https://t.co/wu03WaxiXH",
#             "expanded_url": "https://bit.ly/3yosFWv",
#             "display_url": "bit.ly/3yosFWv",
#             "indices": [
#               229,
#               252
#             ]
#           }
#         ],
#         "user_mentions": [
#           {
#             "screen_name": "Mariagutim",
#             "name": "Mar\u00eda Guti\u00e9rrez",
#             "id": 114244479,
#             "id_str": "114244479",
#             "indices": [
#               105,
#               116
#             ]
#           },
#           {
#             "screen_name": "Hiwook_Jobs",
#             "name": "Hiwook_Jobs",
#             "id": 974053297874178050,
#             "id_str": "974053297874178050",
#             "indices": [
#               120,
#               132
#             ]
#           }
#         ],
#         "symbols": [],
#         "media": [
#           {
#             "id": 1578003707286982658,
#             "id_str": "1578003707286982658",
#             "indices": [
#               266,
#               289
#             ],
#             "media_url": "http://pbs.twimg.com/media/FeYyAtsXEAIKrmB.jpg",
#             "media_url_https": "https://pbs.twimg.com/media/FeYyAtsXEAIKrmB.jpg",
#             "url": "https://t.co/7X0nfl9htI",
#             "display_url": "pic.twitter.com/7X0nfl9htI",
#             "expanded_url": "https://twitter.com/TheBridge_Tech/status/1578003711154176001/photo/1",
#             "type": "photo",
#             "sizes": {
#               "thumb": {
#                 "w": 150,
#                 "h": 150,
#                 "resize": "crop"
#               },
#               "large": {
#                 "w": 1200,
#                 "h": 675,
#                 "resize": "fit"
#               },
#               "small": {
#                 "w": 680,
#                 "h": 383,
#                 "resize": "fit"
#               },
#               "medium": {
#                 "w": 1200,
#                 "h": 675,
#                 "resize": "fit"
#               }
#             }
#           }
#         ]
#       },
#       "extended_entities": {
#         "media": [
#           {
#             "id": 1578003707286982658,
#             "id_str": "1578003707286982658",
#             "indices": [
#               266,
#               289
#             ],
#             "media_url": "http://pbs.twimg.com/media/FeYyAtsXEAIKrmB.jpg",
#             "media_url_https": "https://pbs.twimg.com/media/FeYyAtsXEAIKrmB.jpg",
#             "url": "https://t.co/7X0nfl9htI",
#             "display_url": "pic.twitter.com/7X0nfl9htI",
#             "expanded_url": "https://twitter.com/TheBridge_Tech/status/1578003711154176001/photo/1",
#             "type": "photo",
#             "sizes": {
#               "thumb": {
#                 "w": 150,
#                 "h": 150,
#                 "resize": "crop"
#               },
#               "large": {
#                 "w": 1200,
#                 "h": 675,
#                 "resize": "fit"
#               },
#               "small": {
#                 "w": 680,
#                 "h": 383,
#                 "resize": "fit"
#               },
#               "medium": {
#                 "w": 1200,
#                 "h": 675,
#                 "resize": "fit"
#               }
#             }
#           }
#         ]
#       }
#     },
#     "quote_count": 0,
#     "reply_count": 0,
#     "retweet_count": 1,
#     "favorite_count": 1,
#     "entities": {
#       "hashtags": [],
#       "urls": [
#         {
#           "url": "https://t.co/8WD3VnJZAF",
#           "expanded_url": "https://twitter.com/i/web/status/1578003711154176001",
#           "display_url": "twitter.com/i/web/status/1\u2026",
#           "indices": [
#             106,
#             129
#           ]
#         }
#       ],
#       "user_mentions": [],
#       "symbols": []
#     },
#     "favorited": false,
#     "retweeted": false,
#     "possibly_sensitive": false,
#     "edit_history": {
#       "initial_tweet_id": "1578003711154176001",
#       "edit_tweet_ids": [
#         "1578003711154176001"
#       ]
#     },
#     "edit_controls": {
#       "editable_until_ms": 1665062177000,
#       "edits_remaining": 5
#     },
#     "editable": true,
#     "filter_level": "low",
#     "lang": "es"
#   },
#   "is_quote_status": false,
#   "quote_count": 0,
#   "reply_count": 0,
#   "retweet_count": 0,
#   "favorite_count": 0,
#   "entities": {
#     "hashtags": [],
#     "urls": [],
#     "user_mentions": [
#       {
#         "screen_name": "TheBridge_Tech",
#         "name": "The Bridge",
#         "id": 1162694149956603904,
#         "id_str": "1162694149956603904",
#         "indices": [
#           3,
#           18
#         ]
#       },
#       {
#         "screen_name": "Mariagutim",
#         "name": "Mar\u00eda Guti\u00e9rrez",
#         "id": 114244479,
#         "id_str": "114244479",
#         "indices": [
#           125,
#           136
#         ]
#       }
#     ],
#     "symbols": []
#   },
#   "favorited": false,
#   "retweeted": false,
#   "edit_history": {
#     "initial_tweet_id": "1578246533832654848",
#     "edit_tweet_ids": [
#       "1578246533832654848"
#     ]
#   },
#   "edit_controls": {
#     "editable_until_ms": 1665120070725,
#     "edits_remaining": 5
#   },
#   "editable": false,
#   "filter_level": "low",
#   "lang": "es",
#   "matching_rules": [
#     {
#       "tag": null
#     }
#   ]
# }
# {
#   "created_at": "Wed Oct 05 18:02:07 +0000 2022",
#   "id": 1577720804619571201,
#   "id_str": "1577720804619571201",
#   "text": "RT @TheBridge_Tech: Ya est\u00e1n aqu\u00ed nuestros primeros mini emprendedores \ud83e\udd29 pas\u00e1ndoselo en grande mientras empiezan el proceso de ideaci\u00f3n de\u2026",
#   "source": "<a href=\"http://twitter.com/download/iphone\" rel=\"nofollow\">Twitter for iPhone</a>",
#   "truncated": false,
#   "in_reply_to_status_id": null,
#   "in_reply_to_status_id_str": null,
#   "in_reply_to_user_id": null,
#   "in_reply_to_user_id_str": null,
#   "in_reply_to_screen_name": null,
#   "user": {
#     "id": 1099588676181471233,
#     "id_str": "1099588676181471233",
#     "name": "Flor_Turoninos",
#     "screen_name": "turoninos",
#     "location": "Valladolid, Espa\u00f1a",
#     "url": null,
#     "description": null,
#     "translator_type": "none",
#     "protected": false,
#     "verified": false,
#     "followers_count": 170,
#     "friends_count": 278,
#     "listed_count": 1,
#     "favourites_count": 75827,
#     "statuses_count": 6209,
#     "created_at": "Sun Feb 24 08:35:44 +0000 2019",
#     "utc_offset": null,
#     "time_zone": null,
#     "geo_enabled": true,
#     "lang": null,
#     "contributors_enabled": false,
#     "is_translator": false,
#     "profile_background_color": "F5F8FA",
#     "profile_background_image_url": "",
#     "profile_background_image_url_https": "",
#     "profile_background_tile": false,
#     "profile_link_color": "1DA1F2",
#     "profile_sidebar_border_color": "C0DEED",
#     "profile_sidebar_fill_color": "DDEEF6",
#     "profile_text_color": "333333",
#     "profile_use_background_image": true,
#     "profile_image_url": "http://pbs.twimg.com/profile_images/1099653196077809664/3PWfgS9g_normal.jpg",
#     "profile_image_url_https": "https://pbs.twimg.com/profile_images/1099653196077809664/3PWfgS9g_normal.jpg",
#     "profile_banner_url": "https://pbs.twimg.com/profile_banners/1099588676181471233/1550997765",
#     "default_profile": true,
#     "default_profile_image": false,
#     "following": null,
#     "follow_request_sent": null,
#     "notifications": null,
#     "withheld_in_countries": []
#   },
#   "geo": null,
#   "coordinates": null,
#   "place": null,
#   "contributors": null,
#   "retweeted_status": {
#     "created_at": "Wed Oct 05 13:39:43 +0000 2022",
#     "id": 1577654769098842112,
#     "id_str": "1577654769098842112",
#     "text": "Ya est\u00e1n aqu\u00ed nuestros primeros mini emprendedores \ud83e\udd29 pas\u00e1ndoselo en grande mientras empiezan el proceso de ideaci\u00f3n\u2026 https://t.co/DinbpdCtdc",
#     "display_text_range": [
#       0,
#       140
#     ],
#     "source": "<a href=\"https://mobile.twitter.com\" rel=\"nofollow\">Twitter Web App</a>",
#     "truncated": true,
#     "in_reply_to_status_id": null,
#     "in_reply_to_status_id_str": null,
#     "in_reply_to_user_id": null,
#     "in_reply_to_user_id_str": null,
#     "in_reply_to_screen_name": null,
#     "user": {
#       "id": 1162694149956603904,
#       "id_str": "1162694149956603904",
#       "name": "The Bridge",
#       "screen_name": "TheBridge_Tech",
#       "location": "Paseo de Recoletos, 15, Madrid",
#       "url": "https://www.thebridge.tech/",
#       "description": "Aceleradora de Talento Digital\n\nBootcamps | Corporate Skilling | University Program Management | Startup Factory",
#       "translator_type": "none",
#       "protected": false,
#       "verified": false,
#       "followers_count": 538,
#       "friends_count": 124,
#       "listed_count": 11,
#       "favourites_count": 199,
#       "statuses_count": 523,
#       "created_at": "Sat Aug 17 11:54:55 +0000 2019",
#       "utc_offset": null,
#       "time_zone": null,
#       "geo_enabled": true,
#       "lang": null,
#       "contributors_enabled": false,
#       "is_translator": false,
#       "profile_background_color": "F5F8FA",
#       "profile_background_image_url": "",
#       "profile_background_image_url_https": "",
#       "profile_background_tile": false,
#       "profile_link_color": "1DA1F2",
#       "profile_sidebar_border_color": "C0DEED",
#       "profile_sidebar_fill_color": "DDEEF6",
#       "profile_text_color": "333333",
#       "profile_use_background_image": true,
#       "profile_image_url": "http://pbs.twimg.com/profile_images/1546415533909737474/UgLpusY5_normal.jpg",
#       "profile_image_url_https": "https://pbs.twimg.com/profile_images/1546415533909737474/UgLpusY5_normal.jpg",
#       "profile_banner_url": "https://pbs.twimg.com/profile_banners/1162694149956603904/1660298543",
#       "default_profile": true,
#       "default_profile_image": false,
#       "following": null,
#       "follow_request_sent": null,
#       "notifications": null,
#       "withheld_in_countries": []
#     },
#     "geo": null,
#     "coordinates": null,
#     "place": null,
#     "contributors": null,
#     "is_quote_status": false,
#     "extended_tweet": {
#       "full_text": "Ya est\u00e1n aqu\u00ed nuestros primeros mini emprendedores \ud83e\udd29 pas\u00e1ndoselo en grande mientras empiezan el proceso de ideaci\u00f3n de sus proyectos- \n\nCon el programa de @GenyusSchool descubren su YO emprendedor mientras se divierten\ud83d\udc4f\n\n\u00a1A\u00fan est\u00e1s a tiempo!\ud83d\udc49https://t.co/uaEMCO1jGy https://t.co/80gibJEUcI",
#       "display_text_range": [
#         0,
#         265
#       ],
#       "entities": {
#         "hashtags": [],
#         "urls": [
#           {
#             "url": "https://t.co/uaEMCO1jGy",
#             "expanded_url": "https://bit.ly/3Eky8S2",
#             "display_url": "bit.ly/3Eky8S2",
#             "indices": [
#               242,
#               265
#             ]
#           }
#         ],
#         "user_mentions": [
#           {
#             "screen_name": "GenyusSchool",
#             "name": "Genyus School",
#             "id": 1481678057660424195,
#             "id_str": "1481678057660424195",
#             "indices": [
#               155,
#               168
#             ]
#           }
#         ],
#         "symbols": [],
#         "media": [
#           {
#             "id": 1577653945723486209,
#             "id_str": "1577653945723486209",
#             "indices": [
#               266,
#               289
#             ],
#             "media_url": "http://pbs.twimg.com/media/FeTz56VXgAEoODd.jpg",
#             "media_url_https": "https://pbs.twimg.com/media/FeTz56VXgAEoODd.jpg",
#             "url": "https://t.co/80gibJEUcI",
#             "display_url": "pic.twitter.com/80gibJEUcI",
#             "expanded_url": "https://twitter.com/TheBridge_Tech/status/1577654769098842112/photo/1",
#             "type": "photo",
#             "sizes": {
#               "thumb": {
#                 "w": 150,
#                 "h": 150,
#                 "resize": "crop"
#               },
#               "small": {
#                 "w": 680,
#                 "h": 382,
#                 "resize": "fit"
#               },
#               "medium": {
#                 "w": 1200,
#                 "h": 674,
#                 "resize": "fit"
#               },
#               "large": {
#                 "w": 2048,
#                 "h": 1151,
#                 "resize": "fit"
#               }
#             }
#           }
#         ]
#       },
#       "extended_entities": {
#         "media": [
#           {
#             "id": 1577653945723486209,
#             "id_str": "1577653945723486209",
#             "indices": [
#               266,
#               289
#             ],
#             "media_url": "http://pbs.twimg.com/media/FeTz56VXgAEoODd.jpg",
#             "media_url_https": "https://pbs.twimg.com/media/FeTz56VXgAEoODd.jpg",
#             "url": "https://t.co/80gibJEUcI",
#             "display_url": "pic.twitter.com/80gibJEUcI",
#             "expanded_url": "https://twitter.com/TheBridge_Tech/status/1577654769098842112/photo/1",
#             "type": "photo",
#             "sizes": {
#               "thumb": {
#                 "w": 150,
#                 "h": 150,
#                 "resize": "crop"
#               },
#               "small": {
#                 "w": 680,
#                 "h": 382,
#                 "resize": "fit"
#               },
#               "medium": {
#                 "w": 1200,
#                 "h": 674,
#                 "resize": "fit"
#               },
#               "large": {
#                 "w": 2048,
#                 "h": 1151,
#                 "resize": "fit"
#               }
#             }
#           }
#         ]
#       }
#     },
#     "quote_count": 0,
#     "reply_count": 0,
#     "retweet_count": 2,
#     "favorite_count": 3,
#     "entities": {
#       "hashtags": [],
#       "urls": [
#         {
#           "url": "https://t.co/DinbpdCtdc",
#           "expanded_url": "https://twitter.com/i/web/status/1577654769098842112",
#           "display_url": "twitter.com/i/web/status/1\u2026",
#           "indices": [
#             117,
#             140
#           ]
#         }
#       ],
#       "user_mentions": [],
#       "symbols": []
#     },
#     "favorited": false,
#     "retweeted": false,
#     "possibly_sensitive": false,
#     "edit_history": {
#       "initial_tweet_id": "1577654769098842112",
#       "edit_tweet_ids": [
#         "1577654769098842112"
#       ]
#     },
#     "edit_controls": {
#       "editable_until_ms": 1664978983000,
#       "edits_remaining": 5
#     },
#     "editable": true,
#     "filter_level": "low",
#     "lang": "es"
#   },
#   "is_quote_status": false,
#   "quote_count": 0,
#   "reply_count": 0,
#   "retweet_count": 0,
#   "favorite_count": 0,
#   "entities": {
#     "hashtags": [],
#     "urls": [],
#     "user_mentions": [
#       {
#         "screen_name": "TheBridge_Tech",
#         "name": "The Bridge",
#         "id": 1162694149956603904,
#         "id_str": "1162694149956603904",
#         "indices": [
#           3,
#           18
#         ]
#       }
#     ],
#     "symbols": []
#   },
#   "favorited": false,
#   "retweeted": false,
#   "edit_history": {
#     "initial_tweet_id": "1577720804619571201",
#     "edit_tweet_ids": [
#       "1577720804619571201"
#     ]
#   },
#   "edit_controls": {
#     "editable_until_ms": 1664994727113,
#     "edits_remaining": 5
#   },
#   "editable": false,
#   "filter_level": "low",
#   "lang": "es",
#   "matching_rules": [
#     {
#       "tag": null
#     }
#   ]
# }
# {
#   "created_at": "Wed Oct 05 13:16:46 +0000 2022",
#   "id": 1577648996927012866,
#   "id_str": "1577648996927012866",
#   "text": "RT @TheBridge_Tech: \u00a1Feliz D\u00eda a nuestros Lead Instructors y Teacher Assistants! \ud83c\udf89 Sabemos que en ocasiones un #bootcamp es duro para tod@s\u2026",
#   "source": "<a href=\"http://twitter.com/download/iphone\" rel=\"nofollow\">Twitter for iPhone</a>",
#   "truncated": false,
#   "in_reply_to_status_id": null,
#   "in_reply_to_status_id_str": null,
#   "in_reply_to_user_id": null,
#   "in_reply_to_user_id_str": null,
#   "in_reply_to_screen_name": null,
#   "user": {
#     "id": 763045308095950848,
#     "id_str": "763045308095950848",
#     "name": "Carlos Sevilla",
#     "screen_name": "Carlosevi94",
#     "location": "Sevilla, Espa\u00f1a",
#     "url": null,
#     "description": "Data Scientist.\nPython Lover.",
#     "translator_type": "none",
#     "protected": false,
#     "verified": false,
#     "followers_count": 88,
#     "friends_count": 346,
#     "listed_count": 3,
#     "favourites_count": 355,
#     "statuses_count": 1328,
#     "created_at": "Tue Aug 09 16:12:33 +0000 2016",
#     "utc_offset": null,
#     "time_zone": null,
#     "geo_enabled": false,
#     "lang": null,
#     "contributors_enabled": false,
#     "is_translator": false,
#     "profile_background_color": "F5F8FA",
#     "profile_background_image_url": "",
#     "profile_background_image_url_https": "",
#     "profile_background_tile": false,
#     "profile_link_color": "1DA1F2",
#     "profile_sidebar_border_color": "C0DEED",
#     "profile_sidebar_fill_color": "DDEEF6",
#     "profile_text_color": "333333",
#     "profile_use_background_image": true,
#     "profile_image_url": "http://pbs.twimg.com/profile_images/793829531459149824/75eKabFy_normal.jpg",
#     "profile_image_url_https": "https://pbs.twimg.com/profile_images/793829531459149824/75eKabFy_normal.jpg",
#     "profile_banner_url": "https://pbs.twimg.com/profile_banners/763045308095950848/1478098753",
#     "default_profile": true,
#     "default_profile_image": false,
#     "following": null,
#     "follow_request_sent": null,
#     "notifications": null,
#     "withheld_in_countries": []
#   },
#   "geo": null,
#   "coordinates": null,
#   "place": null,
#   "contributors": null,
#   "retweeted_status": {
#     "created_at": "Wed Oct 05 07:40:47 +0000 2022",
#     "id": 1577564440530124802,
#     "id_str": "1577564440530124802",
#     "text": "\u00a1Feliz D\u00eda a nuestros Lead Instructors y Teacher Assistants! \ud83c\udf89 Sabemos que en ocasiones un #bootcamp es duro para t\u2026 https://t.co/QQBokqxHBh",
#     "display_text_range": [
#       0,
#       140
#     ],
#     "source": "<a href=\"https://mobile.twitter.com\" rel=\"nofollow\">Twitter Web App</a>",
#     "truncated": true,
#     "in_reply_to_status_id": null,
#     "in_reply_to_status_id_str": null,
#     "in_reply_to_user_id": null,
#     "in_reply_to_user_id_str": null,
#     "in_reply_to_screen_name": null,
#     "user": {
#       "id": 1162694149956603904,
#       "id_str": "1162694149956603904",
#       "name": "The Bridge",
#       "screen_name": "TheBridge_Tech",
#       "location": "Paseo de Recoletos, 15, Madrid",
#       "url": "https://www.thebridge.tech/",
#       "description": "Aceleradora de Talento Digital\n\nBootcamps | Corporate Skilling | University Program Management | Startup Factory",
#       "translator_type": "none",
#       "protected": false,
#       "verified": false,
#       "followers_count": 538,
#       "friends_count": 124,
#       "listed_count": 11,
#       "favourites_count": 199,
#       "statuses_count": 523,
#       "created_at": "Sat Aug 17 11:54:55 +0000 2019",
#       "utc_offset": null,
#       "time_zone": null,
#       "geo_enabled": true,
#       "lang": null,
#       "contributors_enabled": false,
#       "is_translator": false,
#       "profile_background_color": "F5F8FA",
#       "profile_background_image_url": "",
#       "profile_background_image_url_https": "",
#       "profile_background_tile": false,
#       "profile_link_color": "1DA1F2",
#       "profile_sidebar_border_color": "C0DEED",
#       "profile_sidebar_fill_color": "DDEEF6",
#       "profile_text_color": "333333",
#       "profile_use_background_image": true,
#       "profile_image_url": "http://pbs.twimg.com/profile_images/1546415533909737474/UgLpusY5_normal.jpg",
#       "profile_image_url_https": "https://pbs.twimg.com/profile_images/1546415533909737474/UgLpusY5_normal.jpg",
#       "profile_banner_url": "https://pbs.twimg.com/profile_banners/1162694149956603904/1660298543",
#       "default_profile": true,
#       "default_profile_image": false,
#       "following": null,
#       "follow_request_sent": null,
#       "notifications": null,
#       "withheld_in_countries": []
#     },
#     "geo": null,
#     "coordinates": null,
#     "place": null,
#     "contributors": null,
#     "is_quote_status": false,
#     "extended_tweet": {
#       "full_text": "\u00a1Feliz D\u00eda a nuestros Lead Instructors y Teacher Assistants! \ud83c\udf89 Sabemos que en ocasiones un #bootcamp es duro para tod@s pero cada d\u00eda dais el \ud83d\udcaf%\n\n\u00a1Gracias por hacer lo #digital mucho m\u00e1s f\u00e1cil!\n\n#diamundialdelosdocentes #data #ciber #desarrollowebfullstack #mkt #uxui #cloud https://t.co/Qnehy8ODCq",
#       "display_text_range": [
#         0,
#         274
#       ],
#       "entities": {
#         "hashtags": [
#           {
#             "text": "bootcamp",
#             "indices": [
#               91,
#               100
#             ]
#           },
#           {
#             "text": "digital",
#             "indices": [
#               168,
#               176
#             ]
#           },
#           {
#             "text": "diamundialdelosdocentes",
#             "indices": [
#               195,
#               219
#             ]
#           },
#           {
#             "text": "data",
#             "indices": [
#               220,
#               225
#             ]
#           },
#           {
#             "text": "ciber",
#             "indices": [
#               226,
#               232
#             ]
#           },
#           {
#             "text": "desarrollowebfullstack",
#             "indices": [
#               233,
#               256
#             ]
#           },
#           {
#             "text": "mkt",
#             "indices": [
#               257,
#               261
#             ]
#           },
#           {
#             "text": "uxui",
#             "indices": [
#               262,
#               267
#             ]
#           },
#           {
#             "text": "cloud",
#             "indices": [
#               268,
#               274
#             ]
#           }
#         ],
#         "urls": [],
#         "user_mentions": [],
#         "symbols": [],
#         "media": [
#           {
#             "id": 1577562273534672896,
#             "id_str": "1577562273534672896",
#             "indices": [
#               275,
#               298
#             ],
#             "media_url": "http://pbs.twimg.com/tweet_video_thumb/FeSgh40XgAAHqai.jpg",
#             "media_url_https": "https://pbs.twimg.com/tweet_video_thumb/FeSgh40XgAAHqai.jpg",
#             "url": "https://t.co/Qnehy8ODCq",
#             "display_url": "pic.twitter.com/Qnehy8ODCq",
#             "expanded_url": "https://twitter.com/TheBridge_Tech/status/1577564440530124802/photo/1",
#             "type": "animated_gif",
#             "video_info": {
#               "aspect_ratio": [
#                 249,
#                 139
#               ],
#               "variants": [
#                 {
#                   "bitrate": 0,
#                   "content_type": "video/mp4",
#                   "url": "https://video.twimg.com/tweet_video/FeSgh40XgAAHqai.mp4"
#                 }
#               ]
#             },
#             "sizes": {
#               "thumb": {
#                 "w": 150,
#                 "h": 150,
#                 "resize": "crop"
#               },
#               "large": {
#                 "w": 498,
#                 "h": 278,
#                 "resize": "fit"
#               },
#               "small": {
#                 "w": 498,
#                 "h": 278,
#                 "resize": "fit"
#               },
#               "medium": {
#                 "w": 498,
#                 "h": 278,
#                 "resize": "fit"
#               }
#             }
#           }
#         ]
#       },
#       "extended_entities": {
#         "media": [
#           {
#             "id": 1577562273534672896,
#             "id_str": "1577562273534672896",
#             "indices": [
#               275,
#               298
#             ],
#             "media_url": "http://pbs.twimg.com/tweet_video_thumb/FeSgh40XgAAHqai.jpg",
#             "media_url_https": "https://pbs.twimg.com/tweet_video_thumb/FeSgh40XgAAHqai.jpg",
#             "url": "https://t.co/Qnehy8ODCq",
#             "display_url": "pic.twitter.com/Qnehy8ODCq",
#             "expanded_url": "https://twitter.com/TheBridge_Tech/status/1577564440530124802/photo/1",
#             "type": "animated_gif",
#             "video_info": {
#               "aspect_ratio": [
#                 249,
#                 139
#               ],
#               "variants": [
#                 {
#                   "bitrate": 0,
#                   "content_type": "video/mp4",
#                   "url": "https://video.twimg.com/tweet_video/FeSgh40XgAAHqai.mp4"
#                 }
#               ]
#             },
#             "sizes": {
#               "thumb": {
#                 "w": 150,
#                 "h": 150,
#                 "resize": "crop"
#               },
#               "large": {
#                 "w": 498,
#                 "h": 278,
#                 "resize": "fit"
#               },
#               "small": {
#                 "w": 498,
#                 "h": 278,
#                 "resize": "fit"
#               },
#               "medium": {
#                 "w": 498,
#                 "h": 278,
#                 "resize": "fit"
#               }
#             }
#           }
#         ]
#       }
#     },
#     "quote_count": 0,
#     "reply_count": 0,
#     "retweet_count": 2,
#     "favorite_count": 2,
#     "entities": {
#       "hashtags": [
#         {
#           "text": "bootcamp",
#           "indices": [
#             91,
#             100
#           ]
#         }
#       ],
#       "urls": [
#         {
#           "url": "https://t.co/QQBokqxHBh",
#           "expanded_url": "https://twitter.com/i/web/status/1577564440530124802",
#           "display_url": "twitter.com/i/web/status/1\u2026",
#           "indices": [
#             117,
#             140
#           ]
#         }
#       ],
#       "user_mentions": [],
#       "symbols": []
#     },
#     "favorited": false,
#     "retweeted": false,
#     "possibly_sensitive": false,
#     "edit_history": {
#       "initial_tweet_id": "1577564440530124802",
#       "edit_tweet_ids": [
#         "1577564440530124802"
#       ]
#     },
#     "edit_controls": {
#       "editable_until_ms": 1664957447000,
#       "edits_remaining": 5
#     },
#     "editable": true,
#     "filter_level": "low",
#     "lang": "es"
#   },
#   "is_quote_status": false,
#   "quote_count": 0,
#   "reply_count": 0,
#   "retweet_count": 0,
#   "favorite_count": 0,
#   "entities": {
#     "hashtags": [
#       {
#         "text": "bootcamp",
#         "indices": [
#           111,
#           120
#         ]
#       }
#     ],
#     "urls": [],
#     "user_mentions": [
#       {
#         "screen_name": "TheBridge_Tech",
#         "name": "The Bridge",
#         "id": 1162694149956603904,
#         "id_str": "1162694149956603904",
#         "indices": [
#           3,
#           18
#         ]
#       }
#     ],
#     "symbols": []
#   },
#   "favorited": false,
#   "retweeted": false,
#   "edit_history": {
#     "initial_tweet_id": "1577648996927012866",
#     "edit_tweet_ids": [
#       "1577648996927012866"
#     ]
#   },
#   "edit_controls": {
#     "editable_until_ms": 1664977606825,
#     "edits_remaining": 5
#   },
#   "editable": false,
#   "filter_level": "low",
#   "lang": "es",
#   "matching_rules": [
#     {
#       "tag": null
#     }
#   ]
# }
# {
#   "created_at": "Wed Oct 05 13:05:01 +0000 2022",
#   "id": 1577646040269864960,
#   "id_str": "1577646040269864960",
#   "text": "RT @TheBridge_Tech: \u00a1Feliz D\u00eda a nuestros Lead Instructors y Teacher Assistants! \ud83c\udf89 Sabemos que en ocasiones un #bootcamp es duro para tod@s\u2026",
#   "source": "<a href=\"http://twitter.com/download/iphone\" rel=\"nofollow\">Twitter for iPhone</a>",
#   "truncated": false,
#   "in_reply_to_status_id": null,
#   "in_reply_to_status_id_str": null,
#   "in_reply_to_user_id": null,
#   "in_reply_to_user_id_str": null,
#   "in_reply_to_screen_name": null,
#   "user": {
#     "id": 1099588676181471233,
#     "id_str": "1099588676181471233",
#     "name": "Flor_Turoninos",
#     "screen_name": "turoninos",
#     "location": "Valladolid, Espa\u00f1a",
#     "url": null,
#     "description": null,
#     "translator_type": "none",
#     "protected": false,
#     "verified": false,
#     "followers_count": 170,
#     "friends_count": 278,
#     "listed_count": 1,
#     "favourites_count": 75827,
#     "statuses_count": 6209,
#     "created_at": "Sun Feb 24 08:35:44 +0000 2019",
#     "utc_offset": null,
#     "time_zone": null,
#     "geo_enabled": true,
#     "lang": null,
#     "contributors_enabled": false,
#     "is_translator": false,
#     "profile_background_color": "F5F8FA",
#     "profile_background_image_url": "",
#     "profile_background_image_url_https": "",
#     "profile_background_tile": false,
#     "profile_link_color": "1DA1F2",
#     "profile_sidebar_border_color": "C0DEED",
#     "profile_sidebar_fill_color": "DDEEF6",
#     "profile_text_color": "333333",
#     "profile_use_background_image": true,
#     "profile_image_url": "http://pbs.twimg.com/profile_images/1099653196077809664/3PWfgS9g_normal.jpg",
#     "profile_image_url_https": "https://pbs.twimg.com/profile_images/1099653196077809664/3PWfgS9g_normal.jpg",
#     "profile_banner_url": "https://pbs.twimg.com/profile_banners/1099588676181471233/1550997765",
#     "default_profile": true,
#     "default_profile_image": false,
#     "following": null,
#     "follow_request_sent": null,
#     "notifications": null,
#     "withheld_in_countries": []
#   },
#   "geo": null,
#   "coordinates": null,
#   "place": null,
#   "contributors": null,
#   "retweeted_status": {
#     "created_at": "Wed Oct 05 07:40:47 +0000 2022",
#     "id": 1577564440530124802,
#     "id_str": "1577564440530124802",
#     "text": "\u00a1Feliz D\u00eda a nuestros Lead Instructors y Teacher Assistants! \ud83c\udf89 Sabemos que en ocasiones un #bootcamp es duro para t\u2026 https://t.co/QQBokqxHBh",
#     "display_text_range": [
#       0,
#       140
#     ],
#     "source": "<a href=\"https://mobile.twitter.com\" rel=\"nofollow\">Twitter Web App</a>",
#     "truncated": true,
#     "in_reply_to_status_id": null,
#     "in_reply_to_status_id_str": null,
#     "in_reply_to_user_id": null,
#     "in_reply_to_user_id_str": null,
#     "in_reply_to_screen_name": null,
#     "user": {
#       "id": 1162694149956603904,
#       "id_str": "1162694149956603904",
#       "name": "The Bridge",
#       "screen_name": "TheBridge_Tech",
#       "location": "Paseo de Recoletos, 15, Madrid",
#       "url": "https://www.thebridge.tech/",
#       "description": "Aceleradora de Talento Digital\n\nBootcamps | Corporate Skilling | University Program Management | Startup Factory",
#       "translator_type": "none",
#       "protected": false,
#       "verified": false,
#       "followers_count": 538,
#       "friends_count": 124,
#       "listed_count": 11,
#       "favourites_count": 199,
#       "statuses_count": 523,
#       "created_at": "Sat Aug 17 11:54:55 +0000 2019",
#       "utc_offset": null,
#       "time_zone": null,
#       "geo_enabled": true,
#       "lang": null,
#       "contributors_enabled": false,
#       "is_translator": false,
#       "profile_background_color": "F5F8FA",
#       "profile_background_image_url": "",
#       "profile_background_image_url_https": "",
#       "profile_background_tile": false,
#       "profile_link_color": "1DA1F2",
#       "profile_sidebar_border_color": "C0DEED",
#       "profile_sidebar_fill_color": "DDEEF6",
#       "profile_text_color": "333333",
#       "profile_use_background_image": true,
#       "profile_image_url": "http://pbs.twimg.com/profile_images/1546415533909737474/UgLpusY5_normal.jpg",
#       "profile_image_url_https": "https://pbs.twimg.com/profile_images/1546415533909737474/UgLpusY5_normal.jpg",
#       "profile_banner_url": "https://pbs.twimg.com/profile_banners/1162694149956603904/1660298543",
#       "default_profile": true,
#       "default_profile_image": false,
#       "following": null,
#       "follow_request_sent": null,
#       "notifications": null,
#       "withheld_in_countries": []
#     },
#     "geo": null,
#     "coordinates": null,
#     "place": null,
#     "contributors": null,
#     "is_quote_status": false,
#     "extended_tweet": {
#       "full_text": "\u00a1Feliz D\u00eda a nuestros Lead Instructors y Teacher Assistants! \ud83c\udf89 Sabemos que en ocasiones un #bootcamp es duro para tod@s pero cada d\u00eda dais el \ud83d\udcaf%\n\n\u00a1Gracias por hacer lo #digital mucho m\u00e1s f\u00e1cil!\n\n#diamundialdelosdocentes #data #ciber #desarrollowebfullstack #mkt #uxui #cloud https://t.co/Qnehy8ODCq",
#       "display_text_range": [
#         0,
#         274
#       ],
#       "entities": {
#         "hashtags": [
#           {
#             "text": "bootcamp",
#             "indices": [
#               91,
#               100
#             ]
#           },
#           {
#             "text": "digital",
#             "indices": [
#               168,
#               176
#             ]
#           },
#           {
#             "text": "diamundialdelosdocentes",
#             "indices": [
#               195,
#               219
#             ]
#           },
#           {
#             "text": "data",
#             "indices": [
#               220,
#               225
#             ]
#           },
#           {
#             "text": "ciber",
#             "indices": [
#               226,
#               232
#             ]
#           },
#           {
#             "text": "desarrollowebfullstack",
#             "indices": [
#               233,
#               256
#             ]
#           },
#           {
#             "text": "mkt",
#             "indices": [
#               257,
#               261
#             ]
#           },
#           {
#             "text": "uxui",
#             "indices": [
#               262,
#               267
#             ]
#           },
#           {
#             "text": "cloud",
#             "indices": [
#               268,
#               274
#             ]
#           }
#         ],
#         "urls": [],
#         "user_mentions": [],
#         "symbols": [],
#         "media": [
#           {
#             "id": 1577562273534672896,
#             "id_str": "1577562273534672896",
#             "indices": [
#               275,
#               298
#             ],
#             "media_url": "http://pbs.twimg.com/tweet_video_thumb/FeSgh40XgAAHqai.jpg",
#             "media_url_https": "https://pbs.twimg.com/tweet_video_thumb/FeSgh40XgAAHqai.jpg",
#             "url": "https://t.co/Qnehy8ODCq",
#             "display_url": "pic.twitter.com/Qnehy8ODCq",
#             "expanded_url": "https://twitter.com/TheBridge_Tech/status/1577564440530124802/photo/1",
#             "type": "animated_gif",
#             "video_info": {
#               "aspect_ratio": [
#                 249,
#                 139
#               ],
#               "variants": [
#                 {
#                   "bitrate": 0,
#                   "content_type": "video/mp4",
#                   "url": "https://video.twimg.com/tweet_video/FeSgh40XgAAHqai.mp4"
#                 }
#               ]
#             },
#             "sizes": {
#               "thumb": {
#                 "w": 150,
#                 "h": 150,
#                 "resize": "crop"
#               },
#               "large": {
#                 "w": 498,
#                 "h": 278,
#                 "resize": "fit"
#               },
#               "small": {
#                 "w": 498,
#                 "h": 278,
#                 "resize": "fit"
#               },
#               "medium": {
#                 "w": 498,
#                 "h": 278,
#                 "resize": "fit"
#               }
#             }
#           }
#         ]
#       },
#       "extended_entities": {
#         "media": [
#           {
#             "id": 1577562273534672896,
#             "id_str": "1577562273534672896",
#             "indices": [
#               275,
#               298
#             ],
#             "media_url": "http://pbs.twimg.com/tweet_video_thumb/FeSgh40XgAAHqai.jpg",
#             "media_url_https": "https://pbs.twimg.com/tweet_video_thumb/FeSgh40XgAAHqai.jpg",
#             "url": "https://t.co/Qnehy8ODCq",
#             "display_url": "pic.twitter.com/Qnehy8ODCq",
#             "expanded_url": "https://twitter.com/TheBridge_Tech/status/1577564440530124802/photo/1",
#             "type": "animated_gif",
#             "video_info": {
#               "aspect_ratio": [
#                 249,
#                 139
#               ],
#               "variants": [
#                 {
#                   "bitrate": 0,
#                   "content_type": "video/mp4",
#                   "url": "https://video.twimg.com/tweet_video/FeSgh40XgAAHqai.mp4"
#                 }
#               ]
#             },
#             "sizes": {
#               "thumb": {
#                 "w": 150,
#                 "h": 150,
#                 "resize": "crop"
#               },
#               "large": {
#                 "w": 498,
#                 "h": 278,
#                 "resize": "fit"
#               },
#               "small": {
#                 "w": 498,
#                 "h": 278,
#                 "resize": "fit"
#               },
#               "medium": {
#                 "w": 498,
#                 "h": 278,
#                 "resize": "fit"
#               }
#             }
#           }
#         ]
#       }
#     },
#     "quote_count": 0,
#     "reply_count": 0,
#     "retweet_count": 2,
#     "favorite_count": 2,
#     "entities": {
#       "hashtags": [
#         {
#           "text": "bootcamp",
#           "indices": [
#             91,
#             100
#           ]
#         }
#       ],
#       "urls": [
#         {
#           "url": "https://t.co/QQBokqxHBh",
#           "expanded_url": "https://twitter.com/i/web/status/1577564440530124802",
#           "display_url": "twitter.com/i/web/status/1\u2026",
#           "indices": [
#             117,
#             140
#           ]
#         }
#       ],
#       "user_mentions": [],
#       "symbols": []
#     },
#     "favorited": false,
#     "retweeted": false,
#     "possibly_sensitive": false,
#     "edit_history": {
#       "initial_tweet_id": "1577564440530124802",
#       "edit_tweet_ids": [
#         "1577564440530124802"
#       ]
#     },
#     "edit_controls": {
#       "editable_until_ms": 1664957447000,
#       "edits_remaining": 5
#     },
#     "editable": true,
#     "filter_level": "low",
#     "lang": "es"
#   },
#   "is_quote_status": false,
#   "quote_count": 0,
#   "reply_count": 0,
#   "retweet_count": 0,
#   "favorite_count": 0,
#   "entities": {
#     "hashtags": [
#       {
#         "text": "bootcamp",
#         "indices": [
#           111,
#           120
#         ]
#       }
#     ],
#     "urls": [],
#     "user_mentions": [
#       {
#         "screen_name": "TheBridge_Tech",
#         "name": "The Bridge",
#         "id": 1162694149956603904,
#         "id_str": "1162694149956603904",
#         "indices": [
#           3,
#           18
#         ]
#       }
#     ],
#     "symbols": []
#   },
#   "favorited": false,
#   "retweeted": false,
#   "edit_history": {
#     "initial_tweet_id": "1577646040269864960",
#     "edit_tweet_ids": [
#       "1577646040269864960"
#     ]
#   },
#   "edit_controls": {
#     "editable_until_ms": 1664976901903,
#     "edits_remaining": 5
#   },
#   "editable": false,
#   "filter_level": "low",
#   "lang": "es",
#   "matching_rules": [
#     {
#       "tag": null
#     }
#   ]
# }
# {
#   "created_at": "Tue Oct 04 16:29:45 +0000 2022",
#   "id": 1577335173523308544,
#   "id_str": "1577335173523308544",
#   "text": "RT @PauMugarra: Recordaros que la semana que viene tenemos la primera quedada #CPS en Madrid, en @TheBridge_Tech, en el que tendremos la gr\u2026",
#   "source": "<a href=\"http://twitter.com/download/iphone\" rel=\"nofollow\">Twitter for iPhone</a>",
#   "truncated": false,
#   "in_reply_to_status_id": null,
#   "in_reply_to_status_id_str": null,
#   "in_reply_to_user_id": null,
#   "in_reply_to_user_id_str": null,
# ...
#           "id_str": "2907682397",
#           "indices": [
#             185,
#             194
#           ]
#         },
#         {
#           "screen_name": "TheBridge_Tech",
#           "name": "The Bridge",
#           "id": 1162694149956603904,
#           "id_str": "1162694149956603904",
#           "indices": [
#             249,
#             264
#           ]
#         }
#       ],
#       "symbols": []
#     }
#   },
#   "quote_count": 2,
#   "reply_count": 1,
#   "retweet_count": 5,
#   "favorite_count": 8,
#   "entities": {
#     "hashtags": [],
#     "urls": [
#       {
#         "url": "https://t.co/XUHbpbOpcz",
#         "expanded_url": "https://twitter.com/i/web/status/1567815140455710721",
#         "display_url": "twitter.com/i/web/status/1\u2026",
#         "indices": [
#           117,
#           140
#         ]
#       }
#     ],
#     "user_mentions": [],
#     "symbols": []
#   },
#   "favorited": false,
#   "retweeted": false,
#   "possibly_sensitive": false,
#   "edit_history": {
#     "initial_tweet_id": "1567815140455710721",
#     "edit_tweet_ids": [
#       "1567815140455710721"
#     ]
#   },
#   "edit_controls": {
#     "editable_until_ms": 1662633032000,
#     "edits_remaining": 5
#   },
#   "editable": false,
#   "filter_level": "low",
#   "lang": "es",
#   "matching_rules": [
#     {
#       "tag": null
#     }
#   ]
# }
# {
#   "created_at": "Thu Sep 08 09:11:02 +0000 2022",
#   "id": 1567802683360219136,
#   "id_str": "1567802683360219136",
#   "text": ".@TheBridge_Tech y @Fujitsu_ES se unen para incrementar el mercado de #ciberseguridad en Espa\u00f1a, que cuenta con una\u2026 https://t.co/jJThaa6xP7",
#   "display_text_range": [
#     0,
#     140
#   ],
#   "source": "<a href=\"https://www.oktopost.com\" rel=\"nofollow\">Oktopost</a>",
#   "truncated": true,
#   "in_reply_to_status_id": null,
#   "in_reply_to_status_id_str": null,
#   "in_reply_to_user_id": null,
#   "in_reply_to_user_id_str": null,
#   "in_reply_to_screen_name": null,
#   "user": {
#     "id": 581925228,
#     "id_str": "581925228",
#     "name": "Fujitsu Espa\u00f1a",
#     "screen_name": "Fujitsu_ES",
#     "location": "Madrid",
#     "url": "http://www.fujitsu.com/es",
#     "description": "Fujitsu es la 3\u00aa Empresa TIC m\u00e1s grande en el mundo. Un proveedor l\u00edder de servicios, soluciones y productos TI. Llevamos m\u00e1s de 40 a\u00f1os en Espa\u00f1a. S\u00edguenos.",
#     "translator_type": "none",
#     "protected": false,
#     "verified": false,
#     "followers_count": 5976,
#     "friends_count": 1664,
#     "listed_count": 218,
#     "favourites_count": 8802,
#     "statuses_count": 8290,
#     "created_at": "Wed May 16 13:39:27 +0000 2012",
#     "utc_offset": null,
#     "time_zone": null,
#     "geo_enabled": false,
#     "lang": null,
#     "contributors_enabled": false,
#     "is_translator": false,
#     "profile_background_color": "C50404",
#     "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#     "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#     "profile_background_tile": false,
#     "profile_link_color": "C50404",
#     "profile_sidebar_border_color": "FFFFFF",
#     "profile_sidebar_fill_color": "DDEEF6",
#     "profile_text_color": "333333",
#     "profile_use_background_image": true,
#     "profile_image_url": "http://pbs.twimg.com/profile_images/1447806320824967171/3fQs9hfD_normal.jpg",
#     "profile_image_url_https": "https://pbs.twimg.com/profile_images/1447806320824967171/3fQs9hfD_normal.jpg",
#     "profile_banner_url": "https://pbs.twimg.com/profile_banners/581925228/1634018902",
#     "default_profile": false,
#     "default_profile_image": false,
#     "following": null,
#     "follow_request_sent": null,
#     "notifications": null,
#     "withheld_in_countries": []
#   },
#   "geo": null,
#   "coordinates": null,
#   "place": null,
#   "contributors": null,
#   "is_quote_status": false,
#   "extended_tweet": {
#     "full_text": ".@TheBridge_Tech y @Fujitsu_ES se unen para incrementar el mercado de #ciberseguridad en Espa\u00f1a, que cuenta con una demanda hoy de 30.000 profesionales. \nL\u00e9elo en @elEconomistaes. https://t.co/7Mw1oG7FzI https://t.co/YTpoK1CITH",
#     "display_text_range": [
#       0,
#       203
#     ],
#     "entities": {
#       "hashtags": [
#         {
#           "text": "ciberseguridad",
#           "indices": [
#             70,
#             85
#           ]
#         }
#       ],
#       "urls": [
#         {
#           "url": "https://t.co/7Mw1oG7FzI",
#           "expanded_url": "https://okt.to/Cuq9dE",
#           "display_url": "okt.to/Cuq9dE",
#           "indices": [
#             180,
#             203
#           ]
#         }
#       ],
#       "user_mentions": [
#         {
#           "screen_name": "TheBridge_Tech",
#           "name": "The Bridge",
#           "id": 1162694149956603904,
#           "id_str": "1162694149956603904",
#           "indices": [
#             1,
#             16
#           ]
#         },
#         {
#           "screen_name": "Fujitsu_ES",
#           "name": "Fujitsu Espa\u00f1a",
#           "id": 581925228,
#           "id_str": "581925228",
#           "indices": [
#             19,
#             30
#           ]
#         },
#         {
#           "screen_name": "elEconomistaes",
#           "name": "elEconomista.es",
#           "id": 166507237,
#           "id_str": "166507237",
#           "indices": [
#             163,
#             178
#           ]
#         }
#       ],
#       "symbols": [],
#       "media": [
#         {
#           "id": 1567802680986181633,
#           "id_str": "1567802680986181633",
#           "indices": [
#             204,
#             227
#           ],
#           "media_url": "http://pbs.twimg.com/media/FcH0O1YWIAE7V8j.jpg",
#           "media_url_https": "https://pbs.twimg.com/media/FcH0O1YWIAE7V8j.jpg",
#           "url": "https://t.co/YTpoK1CITH",
#           "display_url": "pic.twitter.com/YTpoK1CITH",
#           "expanded_url": "https://twitter.com/Fujitsu_ES/status/1567802683360219136/photo/1",
#           "type": "photo",
#           "sizes": {
#             "large": {
#               "w": 1024,
#               "h": 531,
#               "resize": "fit"
#             },
#             "thumb": {
#               "w": 150,
#               "h": 150,
#               "resize": "crop"
#             },
#             "medium": {
#               "w": 1024,
#               "h": 531,
#               "resize": "fit"
#             },
#             "small": {
#               "w": 680,
#               "h": 353,
#               "resize": "fit"
#             }
#           }
#         }
#       ]
#     },
#     "extended_entities": {
#       "media": [
#         {
#           "id": 1567802680986181633,
#           "id_str": "1567802680986181633",
#           "indices": [
#             204,
#             227
#           ],
#           "media_url": "http://pbs.twimg.com/media/FcH0O1YWIAE7V8j.jpg",
#           "media_url_https": "https://pbs.twimg.com/media/FcH0O1YWIAE7V8j.jpg",
#           "url": "https://t.co/YTpoK1CITH",
#           "display_url": "pic.twitter.com/YTpoK1CITH",
#           "expanded_url": "https://twitter.com/Fujitsu_ES/status/1567802683360219136/photo/1",
#           "type": "photo",
#           "sizes": {
#             "large": {
#               "w": 1024,
#               "h": 531,
#               "resize": "fit"
#             },
#             "thumb": {
#               "w": 150,
#               "h": 150,
#               "resize": "crop"
#             },
#             "medium": {
#               "w": 1024,
#               "h": 531,
#               "resize": "fit"
#             },
#             "small": {
#               "w": 680,
#               "h": 353,
#               "resize": "fit"
#             }
#           }
#         }
#       ]
#     }
#   },
#   "quote_count": 0,
#   "reply_count": 0,
#   "retweet_count": 0,
#   "favorite_count": 1,
#   "entities": {
#     "hashtags": [
#       {
#         "text": "ciberseguridad",
#         "indices": [
#           70,
#           85
#         ]
#       }
#     ],
#     "urls": [
#       {
#         "url": "https://t.co/jJThaa6xP7",
#         "expanded_url": "https://twitter.com/i/web/status/1567802683360219136",
#         "display_url": "twitter.com/i/web/status/1\u2026",
#         "indices": [
#           117,
#           140
#         ]
#       }
#     ],
#     "user_mentions": [
#       {
#         "screen_name": "TheBridge_Tech",
#         "name": "The Bridge",
#         "id": 1162694149956603904,
#         "id_str": "1162694149956603904",
#         "indices": [
#           1,
#           16
#         ]
#       },
#       {
#         "screen_name": "Fujitsu_ES",
#         "name": "Fujitsu Espa\u00f1a",
#         "id": 581925228,
#         "id_str": "581925228",
#         "indices": [
#           19,
#           30
#         ]
#       }
#     ],
#     "symbols": []
#   },
#   "favorited": false,
#   "retweeted": false,
#   "possibly_sensitive": false,
#   "edit_history": {
#     "initial_tweet_id": "1567802683360219136",
#     "edit_tweet_ids": [
#       "1567802683360219136"
#     ]
#   },
#   "edit_controls": {
#     "editable_until_ms": 1662630062000,
#     "edits_remaining": 5
#   },
#   "editable": true,
#   "filter_level": "low",
#   "lang": "es",
#   "matching_rules": [
#     {
#       "tag": null
#     }
#   ]
# }
# {
#   "created_at": "Thu Sep 08 08:37:00 +0000 2022",
#   "id": 1567794116418838528,
#   "id_str": "1567794116418838528",
#   "text": "Si quieres potenciar el esp\u00edritu emprendedor de tus hij@s el nuevo programa de @GenyusSchool y @TheBridge_Tech \u00a1es\u2026 https://t.co/XlV1V1q0JI",
#   "display_text_range": [
#     0,
#     140
#   ],
#   "source": "<a href=\"https://about.twitter.com/products/tweetdeck\" rel=\"nofollow\">TweetDeck</a>",
#   "truncated": true,
#   "in_reply_to_status_id": null,
#   "in_reply_to_status_id_str": null,
#   "in_reply_to_user_id": null,
#   "in_reply_to_user_id_str": null,
#   "in_reply_to_screen_name": null,
#   "user": {
#     "id": 1162694149956603904,
#     "id_str": "1162694149956603904",
#     "name": "The Bridge",
#     "screen_name": "TheBridge_Tech",
#     "location": "Paseo de Recoletos, 15, Madrid",
#     "url": "https://www.thebridge.tech/",
#     "description": "Aceleradora de Talento Digital\n\nBootcamps | Corporate Skilling | University Program Management | Startup Factory",
#     "translator_type": "none",
#     "protected": false,
#     "verified": false,
#     "followers_count": 538,
#     "friends_count": 124,
#     "listed_count": 11,
#     "favourites_count": 199,
#     "statuses_count": 523,
#     "created_at": "Sat Aug 17 11:54:55 +0000 2019",
#     "utc_offset": null,
#     "time_zone": null,
#     "geo_enabled": true,
#     "lang": null,
#     "contributors_enabled": false,
#     "is_translator": false,
#     "profile_background_color": "F5F8FA",
#     "profile_background_image_url": "",
#     "profile_background_image_url_https": "",
#     "profile_background_tile": false,
#     "profile_link_color": "1DA1F2",
#     "profile_sidebar_border_color": "C0DEED",
#     "profile_sidebar_fill_color": "DDEEF6",
#     "profile_text_color": "333333",
#     "profile_use_background_image": true,
#     "profile_image_url": "http://pbs.twimg.com/profile_images/1546415533909737474/UgLpusY5_normal.jpg",
#     "profile_image_url_https": "https://pbs.twimg.com/profile_images/1546415533909737474/UgLpusY5_normal.jpg",
#     "profile_banner_url": "https://pbs.twimg.com/profile_banners/1162694149956603904/1660298543",
#     "default_profile": true,
#     "default_profile_image": false,
#     "following": null,
#     "follow_request_sent": null,
#     "notifications": null,
#     "withheld_in_countries": []
#   },
#   "geo": null,
#   "coordinates": null,
#   "place": null,
#   "contributors": null,
#   "is_quote_status": false,
#   "extended_tweet": {
#     "full_text": "Si quieres potenciar el esp\u00edritu emprendedor de tus hij@s el nuevo programa de @GenyusSchool y @TheBridge_Tech \u00a1es tu sitio!\ud83d\ude09\n\n\ud83d\ude4c Un lugar donde aprender desarrollando sus propias ideas y superando retos en equipo.\n\nM\u00e1s info \ud83d\udc49https://t.co/4WZRbwvCK7 https://t.co/0gT0pvDvKG",
#     "display_text_range": [
#       0,
#       248
#     ],
#     "entities": {
#       "hashtags": [],
#       "urls": [
#         {
#           "url": "https://t.co/4WZRbwvCK7",
#           "expanded_url": "https://bit.ly/3TKZN3Q",
#           "display_url": "bit.ly/3TKZN3Q",
#           "indices": [
#             225,
#             248
#           ]
#         }
#       ],
#       "user_mentions": [
#         {
#           "screen_name": "GenyusSchool",
#           "name": "Genyus School",
#           "id": 1481678057660424195,
#           "id_str": "1481678057660424195",
#           "indices": [
#             79,
#             92
#           ]
#         },
#         {
#           "screen_name": "TheBridge_Tech",
#           "name": "The Bridge",
#           "id": 1162694149956603904,
#           "id_str": "1162694149956603904",
#           "indices": [
#             95,
#             110
#           ]
#         }
#       ],
#       "symbols": [],
#       "media": [
#         {
#           "id": 1567406316225794049,
#           "id_str": "1567406316225794049",
#           "indices": [
#             249,
#             272
#           ],
#           "media_url": "http://pbs.twimg.com/media/FcCLvXlXkAEy5K6.jpg",
#           "media_url_https": "https://pbs.twimg.com/media/FcCLvXlXkAEy5K6.jpg",
#           "url": "https://t.co/0gT0pvDvKG",
#           "display_url": "pic.twitter.com/0gT0pvDvKG",
#           "expanded_url": "https://twitter.com/TheBridge_Tech/status/1567794116418838528/photo/1",
#           "type": "photo",
#           "sizes": {
#             "large": {
#               "w": 1080,
#               "h": 1080,
#               "resize": "fit"
#             },
#             "thumb": {
#               "w": 150,
#               "h": 150,
#               "resize": "crop"
#             },
#             "medium": {
#               "w": 1080,
#               "h": 1080,
#               "resize": "fit"
#             },
#             "small": {
#               "w": 680,
#               "h": 680,
#               "resize": "fit"
#             }
#           }
#         }
#       ]
#     },
#     "extended_entities": {
#       "media": [
#         {
#           "id": 1567406316225794049,
#           "id_str": "1567406316225794049",
#           "indices": [
#             249,
#             272
#           ],
#           "media_url": "http://pbs.twimg.com/media/FcCLvXlXkAEy5K6.jpg",
#           "media_url_https": "https://pbs.twimg.com/media/FcCLvXlXkAEy5K6.jpg",
#           "url": "https://t.co/0gT0pvDvKG",
#           "display_url": "pic.twitter.com/0gT0pvDvKG",
#           "expanded_url": "https://twitter.com/TheBridge_Tech/status/1567794116418838528/photo/1",
#           "type": "photo",
#           "sizes": {
#             "large": {
#               "w": 1080,
#               "h": 1080,
#               "resize": "fit"
#             },
#             "thumb": {
#               "w": 150,
#               "h": 150,
#               "resize": "crop"
#             },
#             "medium": {
#               "w": 1080,
#               "h": 1080,
#               "resize": "fit"
#             },
#             "small": {
#               "w": 680,
#               "h": 680,
#               "resize": "fit"
#             }
#           }
#         }
#       ]
#     }
#   },
#   "quote_count": 0,
#   "reply_count": 0,
#   "retweet_count": 1,
#   "favorite_count": 2,
#   "entities": {
#     "hashtags": [],
#     "urls": [
#       {
#         "url": "https://t.co/XlV1V1q0JI",
#         "expanded_url": "https://twitter.com/i/web/status/1567794116418838528",
#         "display_url": "twitter.com/i/web/status/1\u2026",
#         "indices": [
#           116,
#           139
#         ]
#       }
#     ],
#     "user_mentions": [
#       {
#         "screen_name": "GenyusSchool",
#         "name": "Genyus School",
#         "id": 1481678057660424195,
#         "id_str": "1481678057660424195",
#         "indices": [
#           79,
#           92
#         ]
#       },
#       {
#         "screen_name": "TheBridge_Tech",
#         "name": "The Bridge",
#         "id": 1162694149956603904,
#         "id_str": "1162694149956603904",
#         "indices": [
#           95,
#           110
#         ]
#       }
#     ],
#     "symbols": []
#   },
#   "favorited": false,
#   "retweeted": false,
#   "possibly_sensitive": false,
#   "edit_history": {
#     "initial_tweet_id": "1567794116418838528",
#     "edit_tweet_ids": [
#       "1567794116418838528"
#     ]
#   },
#   "edit_controls": {
#     "editable_until_ms": 1662628020000,
#     "edits_remaining": 5
#   },
#   "editable": true,
#   "filter_level": "low",
#   "lang": "es",
#   "matching_rules": [
#     {
#       "tag": null
#     }
#   ]
# }

# %% [markdown]
# #### Con el siguiente código extraemos la información de la API y la guardo en un DataFrame.
#
# El fichero solo contiene datos hasta principios desde Septiembre

# %%
db = pd.DataFrame(columns=['identity', 'text', 'created', 'user_id', 
                               'user_name', 'user_screen_name', 'quote', 'reply', 'retweet', 'favorite']) 
tweets= tweepy.Cursor(api.search_full_archive,'development','@TheBridge_Tech').items(250)
    
list_messages = [tweet for tweet in tweets] 
i = 1  
    
for tweet in list_messages: 
    identity = tweet._json["id"] 
    text = tweet._json["text"] 
    created = tweet._json["created_at"] 
    user_id = tweet._json["user"]["id"]
    user_name = tweet._json["user"]["name"] 
    user_screen_name = tweet._json["user"]["screen_name"] 
    quote = tweet._json["quote_count"] 
    reply = tweet._json["reply_count"] 
    retweet = tweet._json["retweet_count"]
    favorite = tweet._json["favorite_count"]

  


    ith_tweet = [identity, text, created, user_id, user_name, user_screen_name, quote, reply, retweet, favorite]
    print(ith_tweet)
    db.loc[len(db)] = ith_tweet
    i = i+1
db.head()
# Out:
# [1578613094191796224, 'Gente muy agradable en @TheBridge_Tech , te ries mucho en el dia a dia. El tema es que pasas tanto tiempo trabajand… https://t.co/mRdVPEb9b2', 'Sat Oct 08 05:07:45 +0000 2022', 1578095844569514011, 'Rocket', '75_Rocket_', 0, 0, 0, 0]
# [1578246533832654848, 'RT @TheBridge_Tech: El próximo martes 11 de octubre no te pierdas la sesión sobre dependencia profesional 😫 con la psicóloga @Mariagutim de…', 'Fri Oct 07 04:51:10 +0000 2022', 1099588676181471233, 'Flor_Turoninos', 'turoninos', 0, 0, 0, 0]
# [1577720804619571201, 'RT @TheBridge_Tech: Ya están aquí nuestros primeros mini emprendedores 🤩 pasándoselo en grande mientras empiezan el proceso de ideación de…', 'Wed Oct 05 18:02:07 +0000 2022', 1099588676181471233, 'Flor_Turoninos', 'turoninos', 0, 0, 0, 0]
# [1577648996927012866, 'RT @TheBridge_Tech: ¡Feliz Día a nuestros Lead Instructors y Teacher Assistants! 🎉 Sabemos que en ocasiones un #bootcamp es duro para tod@s…', 'Wed Oct 05 13:16:46 +0000 2022', 763045308095950848, 'Carlos Sevilla', 'Carlosevi94', 0, 0, 0, 0]
# [1577646040269864960, 'RT @TheBridge_Tech: ¡Feliz Día a nuestros Lead Instructors y Teacher Assistants! 🎉 Sabemos que en ocasiones un #bootcamp es duro para tod@s…', 'Wed Oct 05 13:05:01 +0000 2022', 1099588676181471233, 'Flor_Turoninos', 'turoninos', 0, 0, 0, 0]
# [1577335173523308544, 'RT @PauMugarra: Recordaros que la semana que viene tenemos la primera quedada #CPS en Madrid, en @TheBridge_Tech, en el que tendremos la gr…', 'Tue Oct 04 16:29:45 +0000 2022', 7154412, 'Javier G. Recuenco', 'Recuenco', 0, 0, 0, 0]
# [1577334577701453827, 'Recordaros que la semana que viene tenemos la primera quedada #CPS en Madrid, en @TheBridge_Tech, en el que tendrem… https://t.co/Qv8iOvnwmR', 'Tue Oct 04 16:27:23 +0000 2022', 1003872445, 'Pau Mugarra', 'PauMugarra', 0, 0, 2, 12]
# [1577027194316296193, 'RT @formacion_fuc3: El desarrollador web es uno de los perfiles más demandados en el mercado laboral 📈\n\nDescubre nuestro #bootcamp Desarrol…', 'Mon Oct 03 20:05:57 +0000 2022', 1099588676181471233, 'Flor_Turoninos', 'turoninos', 0, 0, 0, 0]
# [1577027171272429568, 'RT @TheBridge_Tech: ¡Vuelven las #becas Digital Talent Pipeline! \n1⃣0⃣0⃣ becas para formarte en la próxima edición de nuestros #bootcamp en…', 'Mon Oct 03 20:05:52 +0000 2022', 1099588676181471233, 'Flor_Turoninos', 'turoninos', 0, 0, 0, 0]
# [1576966916844924928, 'RT @Apiuxtecnologia: ¿Eres o quieres ser talento IT y estás en España? 🇪🇸 Si la respuesta es sí, te contamos que tenemos alianzas con @IDBo…', 'Mon Oct 03 16:06:26 +0000 2022', 1392422091434168323, 'ID Bootcamps', 'IDBootcamps', 0, 0, 0, 0]
# [1576919468206592001, 'RT @formacion_fuc3: El desarrollador web es uno de los perfiles más demandados en el mercado laboral 📈\n\nDescubre nuestro #bootcamp Desarrol…', 'Mon Oct 03 12:57:53 +0000 2022', 1162694149956603904, 'The Bridge', 'TheBridge_Tech', 0, 0, 0, 0]
# [1576903650319941632, 'RT @formacion_fuc3: El desarrollador web es uno de los perfiles más demandados en el mercado laboral 📈\n\nDescubre nuestro #bootcamp Desarrol…', 'Mon Oct 03 11:55:02 +0000 2022', 1157259865389244417, '#burbujadev', 'burbujadev', 0, 0, 0, 0]
# [1576902991507922944, 'El desarrollador web es uno de los perfiles más demandados en el mercado laboral 📈\n\nDescubre nuestro #bootcamp Desa… https://t.co/hMjrs9m2DL', 'Mon Oct 03 11:52:25 +0000 2022', 2529499620, 'Formación Fundación Universidad Carlos III', 'formacion_fuc3', 0, 0, 3, 3]
# [1576856703349374976, '@jorgegrev @TheBridge_Tech Enhorabuena crack!', 'Mon Oct 03 08:48:29 +0000 2022', 706520411551494145, 'JoseSola', 'Jose_Sola_', 0, 0, 0, 1]
# [1575553072453255168, 'RT @bertinha84: Hoy por fin ve la luz mi primer Case Study público. Un trabajo intensivo de fin de bootcamp realizado con un cliente real @…', 'Thu Sep 29 18:28:19 +0000 2022', 21478536, 'JOSE MANUEL AZORIN', 'jazorin', 0, 0, 0, 0]
# [1575481610845458433, 'RT @bertinha84: Hoy por fin ve la luz mi primer Case Study público. Un trabajo intensivo de fin de bootcamp realizado con un cliente real @…', 'Thu Sep 29 13:44:21 +0000 2022', 917321990465351681, 'emancipaTIC', 'emancipaTIC', 0, 0, 0, 0]
# [1575258895953666048, 'RT @bertinha84: Hoy por fin ve la luz mi primer Case Study público. Un trabajo intensivo de fin de bootcamp realizado con un cliente real @…', 'Wed Sep 28 22:59:22 +0000 2022', 127000294, 'Bea Jimenez', 'beajmnz', 0, 0, 0, 0]
# [1575217357105946624, 'Hoy por fin ve la luz mi primer Case Study público. Un trabajo intensivo de fin de bootcamp realizado con un client… https://t.co/YFaoDn7Sqx', 'Wed Sep 28 20:14:18 +0000 2022', 604485175, 'Berta Otero', 'bertinha84', 0, 0, 3, 4]
# [1575090866167099392, 'RT @TheBridge_Tech: ¡Nuevo acuerdo de colaboración con @michaelpage_es! 🤝\n\n👩\u200d💻Alianza clave en nuestro objetivo de reducir la brecha de com…', 'Wed Sep 28 11:51:40 +0000 2022', 1099588676181471233, 'Flor_Turoninos', 'turoninos', 0, 0, 0, 0]
# [1574849353172373504, '¿Eres o quieres ser talento IT y estás en España? 🇪🇸 Si la respuesta es sí, te contamos que tenemos alianzas con… https://t.co/oVzPkq41zc', 'Tue Sep 27 19:51:59 +0000 2022', 1391838162830385165, 'Apiux Tecnología', 'Apiuxtecnologia', 0, 1, 1, 2]
# [1574345812456476674, 'RT @TheBridge_Tech: ¡Estamos muy orgullosos de formar equipo junto a @Stemdo_io! Participando en la formación de sus futuros empleados con…', 'Mon Sep 26 10:31:06 +0000 2022', 1099588676181471233, 'Flor_Turoninos', 'turoninos', 0, 0, 0, 0]
# [1574325590915784704, 'RT @TheBridge_Tech: ¡Estamos muy orgullosos de formar equipo junto a @Stemdo_io! Participando en la formación de sus futuros empleados con…', 'Mon Sep 26 09:10:45 +0000 2022', 1127630178644054018, 'STEM ai', 'stem_ai', 0, 0, 0, 0]
# [1573424720791363589, 'RT @PauMugarra: Y seguimos con lo prometido:\n\nPrimera quedada de la comunidad #CPS en Madrid 🚀:\nhttps://t.co/xnWjKu6fPi\nen un espacio cedid…', 'Fri Sep 23 21:31:00 +0000 2022', 568101757, 'Imanol Anta', 'imanolanta00', 0, 0, 0, 0]
# [1573388631481483279, "RT @CourseReport: 🏆 We're rounding up the 16 Best UI/UX Design Bootcamps of 2022, including @Shillington_, @Skillcrush, @Springboard, @TheB…", 'Fri Sep 23 19:07:36 +0000 2022', 1262459681693409281, 'Michael Oluwaseun', 'Mayorofgraphics', 0, 0, 0, 0]
# [1573339558204567554, 'RT @PauMugarra: Y seguimos con lo prometido:\n\nPrimera quedada de la comunidad #CPS en Madrid 🚀:\nhttps://t.co/xnWjKu6fPi\nen un espacio cedid…', 'Fri Sep 23 15:52:36 +0000 2022', 1393908772754575360, 'The Sport Solution', 'ASportSolution', 0, 0, 0, 0]
# [1573300097156251649, 'RT @PauMugarra: Y seguimos con lo prometido:\n\nPrimera quedada de la comunidad #CPS en Madrid 🚀:\nhttps://t.co/xnWjKu6fPi\nen un espacio cedid…', 'Fri Sep 23 13:15:48 +0000 2022', 1099588676181471233, 'Flor_Turoninos', 'turoninos', 0, 0, 0, 0]
# [1573279920440201216, 'RT @PauMugarra: Y seguimos con lo prometido:\n\nPrimera quedada de la comunidad #CPS en Madrid 🚀:\nhttps://t.co/xnWjKu6fPi\nen un espacio cedid…', 'Fri Sep 23 11:55:37 +0000 2022', 1162694149956603904, 'The Bridge', 'TheBridge_Tech', 0, 0, 0, 0]
# [1573257226353053696, 'RT @PauMugarra: Y seguimos con lo prometido:\n\nPrimera quedada de la comunidad #CPS en Madrid 🚀:\nhttps://t.co/xnWjKu6fPi\nen un espacio cedid…', 'Fri Sep 23 10:25:27 +0000 2022', 12085582, 'diegodl', 'diegodl', 0, 0, 0, 0]
# [1573253187817115648, 'RT @PauMugarra: Y seguimos con lo prometido:\n\nPrimera quedada de la comunidad #CPS en Madrid 🚀:\nhttps://t.co/xnWjKu6fPi\nen un espacio cedid…', 'Fri Sep 23 10:09:24 +0000 2022', 1252305008357527553, 'fyustas', 'fyustas1', 0, 0, 0, 0]
# [1573246948693651456, 'Y seguimos con lo prometido:\n\nPrimera quedada de la comunidad #CPS en Madrid 🚀:\nhttps://t.co/xnWjKu6fPi\nen un espac… https://t.co/QCRdQH5aI7', 'Fri Sep 23 09:44:36 +0000 2022', 1003872445, 'Pau Mugarra', 'PauMugarra', 4, 0, 7, 20]
# [1573232184454172674, '@TheBridge_Tech @valerybriz @graphext ¡Muchas gracias a @TheBridge_Tech por alojarnos! 🔥', 'Fri Sep 23 08:45:56 +0000 2022', 1494355208473874438, 'PyData Madrid', 'PyDataMadrid', 0, 0, 0, 1]
# [1573218909167271936, 'RT @TheBridge_Tech: Ayer pudimos disfrutar del eventazo de @PyDataMadrid en nuestro palacio🙌Conocimos un montón sobre acelerar flujos de da…', 'Fri Sep 23 07:53:11 +0000 2022', 1533105519447404544, 'PyBot', 'PythonBot_By_PM', 0, 0, 0, 0]
# [1573218843362836482, 'RT @TheBridge_Tech: Ayer pudimos disfrutar del eventazo de @PyDataMadrid en nuestro palacio🙌Conocimos un montón sobre acelerar flujos de da…', 'Fri Sep 23 07:52:55 +0000 2022', 1099588676181471233, 'Flor_Turoninos', 'turoninos', 0, 0, 0, 0]
# [1573213829303275524, 'RT @TheBridge_Tech: Ayer pudimos disfrutar del eventazo de @PyDataMadrid en nuestro palacio🙌Conocimos un montón sobre acelerar flujos de da…', 'Fri Sep 23 07:33:00 +0000 2022', 1494355208473874438, 'PyData Madrid', 'PyDataMadrid', 0, 0, 0, 0]
# [1573211107665367047, 'RT @TheBridge_Tech: Ayer pudimos disfrutar del eventazo de @PyDataMadrid en nuestro palacio🙌Conocimos un montón sobre acelerar flujos de da…', 'Fri Sep 23 07:22:11 +0000 2022', 975452621522853890, 'Interdisciplinarians.org', 'e_nterdiscipl', 0, 0, 0, 0]
# [1573061969799782403, 'RT @TheBridge_Tech: ¿Buscando un empleo en #DataScience? Asiste a AI Careers, el primer evento en Analítica de Datos e Inteligencia Artific…', 'Thu Sep 22 21:29:34 +0000 2022', 992943418052460544, 'Ricardo Vázquez', 'ricardo_ik_ahau', 0, 0, 0, 0]
# [1573049478105690112, 'RT @PyDataMadrid: Ya está abierto el registro para nuestra reunión de septiembre: 🔥 Acelerando flujos de datos y modelos de aprendizaje\n\nht…', 'Thu Sep 22 20:39:56 +0000 2022', 1311739853307027457, 'CinderellaMan', 'Huertaspedia', 0, 0, 0, 0]
# [1572919458116833282, 'RT @TheBridge_Tech: ¿Buscando un empleo en #DataScience? Asiste a AI Careers, el primer evento en Analítica de Datos e Inteligencia Artific…', 'Thu Sep 22 12:03:16 +0000 2022', 1099588676181471233, 'Flor_Turoninos', 'turoninos', 0, 0, 0, 0]
# [1572916570153979905, 'Estamos muy contentos de colaborar desde @TheBridge_Tech en esta iniciativa de @Stemdo_io porque tenemos que colabo… https://t.co/g1d9zLibxG', 'Thu Sep 22 11:51:48 +0000 2022', 12085582, 'diegodl', 'diegodl', 0, 0, 0, 2]
# [1571528997971922945, '@valerybriz @graphext @TheBridge_Tech Hemos llenado el aforo ⚠️ pero ¡aún estás a tiempo de apuntarte a la lista de… https://t.co/us0CULeBJE', 'Sun Sep 18 15:58:05 +0000 2022', 1494355208473874438, 'PyData Madrid', 'PyDataMadrid', 0, 0, 0, 1]
# [1570761257355182083, 'RT @graphext: Next week we are collaborating with 🐍 @PyDataMadrid, @IEBigData, and @TheBridge_Tech  to talk about 🔥Accelerating Data Flows…', 'Fri Sep 16 13:07:21 +0000 2022', 1494355208473874438, 'PyData Madrid', 'PyDataMadrid', 0, 0, 0, 0]
# [1570744256104628226, 'Next week we are collaborating with 🐍 @PyDataMadrid, @IEBigData, and @TheBridge_Tech  to talk about 🔥Accelerating D… https://t.co/45a4bCrHqa', 'Fri Sep 16 11:59:48 +0000 2022', 2907682397, 'graphext', 'graphext', 1, 1, 1, 2]
# [1570731459304095744, 'RT @TheBridge_Tech: ¡Estamos de enhorabuena! Lanzamos un nuevo programa de #desarrollowebfullstack con la @fundacionuc3! Muy ilusionados de…', 'Fri Sep 16 11:08:57 +0000 2022', 2227356042, 'Camino', 'Ego_sumergo', 0, 0, 0, 0]
# [1570708211866677249, 'Esta semana la gerente de @BiohubVLC @sabrinafemenia ha  firmado un convenio de colaboración con @TheBridge_Tech pa… https://t.co/Z86kclyUpe', 'Fri Sep 16 09:36:34 +0000 2022', 1131933723681800193, 'Biohub VLC', 'BiohubVLC', 0, 0, 0, 2]
# [1570687218565656577, '❗ Interesante beca formativa.\n\nℹ Desde el COITCV-AVIT hemos firmando un convenio de colaboración con… https://t.co/t0ymaZT05e', 'Fri Sep 16 08:13:09 +0000 2022', 1073622740, 'COITCV/AVIT', 'COITCV', 0, 0, 0, 0]
# [1570528822382170112, 'RT @sanhuerga: Hoy he hecho el primer mind map de mi vida entera gracias a @TheBridge_Tech \nDía 3. Aprendiendo muchisísimo.¡Comenzamos! #ux…', 'Thu Sep 15 21:43:44 +0000 2022', 1099588676181471233, 'Flor_Turoninos', 'turoninos', 0, 0, 0, 0]
# [1570460916478611457, '@AnaWhitewolf @IronhackMAD @ISDICoders @Ubiqum @4GeeksAcademyES @hackaboss_ @KeepCoding_ @uxerschool… https://t.co/X2qALaBWJX', 'Thu Sep 15 17:13:54 +0000 2022', 41110484, 'Raúl Cotrina', 'raulcotrina', 0, 0, 0, 3]
# [1570422003366072320, '@raulcotrina @IronhackMAD @ISDICoders @Ubiqum @4GeeksAcademyES @hackaboss_ @KeepCoding_ @uxerschool @TheBridge_Tech… https://t.co/UJB1z3kz62', 'Thu Sep 15 14:39:17 +0000 2022', 210026854, 'Ana Amar🎃', 'AnaWhitewolf', 0, 1, 0, 3]
# [1570401438760591360, 'RT @TheBridge_Tech: ¡Acabamos de firmar un acuerdo con @BiohubVLC! 🤝Contribuimos así a cubrir la necesidad de profesionales digitales en un…', 'Thu Sep 15 13:17:34 +0000 2022', 1099588676181471233, 'Flor_Turoninos', 'turoninos', 0, 0, 0, 0]
# [1570359304859037697, 'RT @TheBridge_Tech: ¡Acabamos de firmar un acuerdo con @BiohubVLC! 🤝Contribuimos así a cubrir la necesidad de profesionales digitales en un…', 'Thu Sep 15 10:30:08 +0000 2022', 1051649960, 'Fabricio Cavalcante', 'Fabriciosx', 0, 0, 0, 0]
# [1570317872567558150, '❗ Interesante descuento en formación.\n\nℹ Desde el COITCV-AVIT hemos firmando un convenio de colaboración con… https://t.co/8IhdXjaBEE', 'Thu Sep 15 07:45:30 +0000 2022', 1073622740, 'COITCV/AVIT', 'COITCV', 0, 0, 0, 1]
# [1570296268190097408, 'RT @TheBridge_Tech: Si te interesa el mundo del dato, python... ¡Tenemos nuevo evento de #DataScience de la mano de @PyDataMadrid! Contarem…', 'Thu Sep 15 06:19:39 +0000 2022', 1494355208473874438, 'PyData Madrid', 'PyDataMadrid', 0, 0, 0, 0]
# [1570107400144801801, 'RT @TheBridge_Tech: Si te interesa el mundo del dato, python... ¡Tenemos nuevo evento de #DataScience de la mano de @PyDataMadrid! Contarem…', 'Wed Sep 14 17:49:10 +0000 2022', 1099588676181471233, 'Flor_Turoninos', 'turoninos', 0, 0, 0, 0]
# [1570092050107990021, 'RT @sanhuerga: Hoy he hecho el primer mind map de mi vida entera gracias a @TheBridge_Tech \nDía 3. Aprendiendo muchisísimo.¡Comenzamos! #ux…', 'Wed Sep 14 16:48:10 +0000 2022', 1155468348139982848, 'JuanAlvareZabala', 'AlvareZabala', 0, 0, 0, 0]
# [1570091960911659009, '@sanhuerga @TheBridge_Tech Fantástico 👏👏👏', 'Wed Sep 14 16:47:49 +0000 2022', 2390191837, 'LaSeñoenlaRadioTdF', 'LaSenioenRadio', 0, 0, 0, 0]
# [1570049430807785472, 'Hoy he hecho el primer mind map de mi vida entera gracias a @TheBridge_Tech \nDía 3. Aprendiendo muchisísimo.¡Comenz… https://t.co/VqeJf18YyE', 'Wed Sep 14 13:58:49 +0000 2022', 394734366, 'Sandra Huerga', 'sanhuerga', 0, 1, 2, 5]
# [1570019983291453441, '@TheBridge_Tech y Fujitsu se unen para cubrir la demanda de profesionales en #ciberseguridad  en España.\n✅Mira la n… https://t.co/XUpAsBnX5i', 'Wed Sep 14 12:01:48 +0000 2022', 1327588137346998273, 'DIGITAL INNOVATION NEWS', 'innovation_news', 0, 0, 0, 1]
# [1570013847884369922, 'RT @TheBridge_Tech: Si te interesa el mundo del dato, python... ¡Tenemos nuevo evento de #DataScience de la mano de @PyDataMadrid! Contarem…', 'Wed Sep 14 11:37:25 +0000 2022', 1398866593237508100, 'Twitchi', 'CodeWithTwitchi', 0, 0, 0, 0]
# [1570013385923743744, 'RT @TheBridge_Tech: Si te interesa el mundo del dato, python... ¡Tenemos nuevo evento de #DataScience de la mano de @PyDataMadrid! Contarem…', 'Wed Sep 14 11:35:35 +0000 2022', 1533105519447404544, 'PyBot', 'PythonBot_By_PM', 0, 0, 0, 0]
# [1569424576559435778, 'RT @Fujitsu_ES: .@TheBridge_Tech formará a los futuros profesionales en ciberseguridad de @Fujitsu_ES ▶ https://t.co/a7XYEw0DMh https://t.c…', 'Mon Sep 12 20:35:52 +0000 2022', 1641440478, 'Oscar Tamargo', 'otamargot', 0, 0, 0, 0]
# [1569355311227568130, '.@TheBridge_Tech formará a los futuros profesionales en ciberseguridad de @Fujitsu_ES ▶ https://t.co/a7XYEw0DMh https://t.co/rgmUH4Susw', 'Mon Sep 12 16:00:38 +0000 2022', 581925228, 'Fujitsu España', 'Fujitsu_ES', 0, 0, 1, 4]
# [1569317508267532288, 'RT @TheBridge_Tech: Mañana a las 18.30h tenemos otra de las sesiones sobre "Emotional Wellness" 🧘\u200d♀️, esta vez @Mariagutim de @Hiwook_Jobs…', 'Mon Sep 12 13:30:25 +0000 2022', 1099588676181471233, 'Flor_Turoninos', 'turoninos', 0, 0, 0, 0]
# [1567900039711686656, 'RT @PyDataMadrid: Ya está abierto el registro para nuestra reunión de septiembre: 🔥 Acelerando flujos de datos y modelos de aprendizaje\n\nht…', 'Thu Sep 08 15:37:54 +0000 2022', 1565028593629003777, 'Celia López', 'read_the_code', 0, 0, 0, 0]
# [1567870884689444866, 'RT @TheBridge_Tech: Si quieres potenciar el espíritu emprendedor de tus hij@s el nuevo programa de @GenyusSchool y @TheBridge_Tech ¡es tu s…', 'Thu Sep 08 13:42:03 +0000 2022', 1099588676181471233, 'Flor_Turoninos', 'turoninos', 0, 0, 0, 0]
# [1567870857774604288, 'RT @PyDataMadrid: Ya está abierto el registro para nuestra reunión de septiembre: 🔥 Acelerando flujos de datos y modelos de aprendizaje\n\nht…', 'Thu Sep 08 13:41:56 +0000 2022', 1099588676181471233, 'Flor_Turoninos', 'turoninos', 0, 0, 0, 0]
# [1567829433175756801, 'RT @PyDataMadrid: Ya está abierto el registro para nuestra reunión de septiembre: 🔥 Acelerando flujos de datos y modelos de aprendizaje\n\nht…', 'Thu Sep 08 10:57:20 +0000 2022', 1162694149956603904, 'The Bridge', 'TheBridge_Tech', 0, 0, 0, 0]
# [1567817628453949441, 'RT @PyDataMadrid: Ya está abierto el registro para nuestra reunión de septiembre: 🔥 Acelerando flujos de datos y modelos de aprendizaje\n\nht…', 'Thu Sep 08 10:10:25 +0000 2022', 1367036537943244803, 'Juan Luis Cano Rodríguez', 'juanluisback', 0, 0, 0, 0]
# [1567815140455710721, 'Ya está abierto el registro para nuestra reunión de septiembre: 🔥 Acelerando flujos de datos y modelos de aprendiza… https://t.co/XUHbpbOpcz', 'Thu Sep 08 10:00:32 +0000 2022', 1494355208473874438, 'PyData Madrid', 'PyDataMadrid', 2, 1, 5, 8]
# [1567802683360219136, '.@TheBridge_Tech y @Fujitsu_ES se unen para incrementar el mercado de #ciberseguridad en España, que cuenta con una… https://t.co/jJThaa6xP7', 'Thu Sep 08 09:11:02 +0000 2022', 581925228, 'Fujitsu España', 'Fujitsu_ES', 0, 0, 0, 1]
# [1567794116418838528, 'Si quieres potenciar el espíritu emprendedor de tus hij@s el nuevo programa de @GenyusSchool y @TheBridge_Tech ¡es… https://t.co/XlV1V1q0JI', 'Thu Sep 08 08:37:00 +0000 2022', 1162694149956603904, 'The Bridge', 'TheBridge_Tech', 0, 0, 1, 2]
#               identity                                               text  \
# 0  1578613094191796224  Gente muy agradable en @TheBridge_Tech , te ri...
# 1  1578246533832654848  RT @TheBridge_Tech: El próximo martes 11 de oc...
# 2  1577720804619571201  RT @TheBridge_Tech: Ya están aquí nuestros pri...
# 3  1577648996927012866  RT @TheBridge_Tech: ¡Feliz Día a nuestros Lead...
# 4  1577646040269864960  RT @TheBridge_Tech: ¡Feliz Día a nuestros Lead...
#
#                           created              user_id       user_name  \
# 0  Sat Oct 08 05:07:45 +0000 2022  1578095844569514011          Rocket
# 1  Fri Oct 07 04:51:10 +0000 2022  1099588676181471233  Flor_Turoninos
# 2  Wed Oct 05 18:02:07 +0000 2022  1099588676181471233  Flor_Turoninos
# 3  Wed Oct 05 13:16:46 +0000 2022   763045308095950848  Carlos Sevilla
# 4  Wed Oct 05 13:05:01 +0000 2022  1099588676181471233  Flor_Turoninos
#
#   user_screen_name  quote  reply  retweet  favorite
# 0       75_Rocket_      0      0        0         0
# 1        turoninos      0      0        0         0
# 2        turoninos      0      0        0         0
# 3      Carlosevi94      0      0        0         0
# 4        turoninos      0      0        0         0

# %%
db.head()
# Out:
#               identity                                               text  \
# 2  1577720804619571201  RT @TheBridge_Tech: Ya están aquí nuestros pri...
# 3  1577648996927012866  RT @TheBridge_Tech: ¡Feliz Día a nuestros Lead...
# 4  1577646040269864960  RT @TheBridge_Tech: ¡Feliz Día a nuestros Lead...
# 5  1577335173523308544  RT @PauMugarra: Recordaros que la semana que v...
# 6  1577334577701453827  Recordaros que la semana que viene tenemos la ...
#
#                     created              user_id           user_name  \
# 2 2022-10-05 18:02:07+00:00  1099588676181471233      Flor_Turoninos
# 3 2022-10-05 13:16:46+00:00   763045308095950848      Carlos Sevilla
# 4 2022-10-05 13:05:01+00:00  1099588676181471233      Flor_Turoninos
# 5 2022-10-04 16:29:45+00:00              7154412  Javier G. Recuenco
# 6 2022-10-04 16:27:23+00:00           1003872445         Pau Mugarra
#
#   user_screen_name  quote  reply  retweet  favorite
# 2        turoninos      0      0        0         0
# 3      Carlosevi94      0      0        0         0
# 4        turoninos      0      0        0         0
# 5         Recuenco      0      0        0         0
# 6       PauMugarra      0      0        2        12

# %% [markdown]
# #### Convertimos la columna *created* en fecha y ajustamos los datos obtenidos a las condiciones de las fechas indicadas en el caso.

# %%
db['created'] = pd.to_datetime(db['created'])

# %%
db = db.drop(db[db['created']>'2022-10-05 18:02:07+00:00'].index)

# %%
db.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 70 entries, 0 to 69
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   identity          70 non-null     int64
#  1   text              70 non-null     object
#  2   created           70 non-null     datetime64[ns, UTC]
#  3   user_id           70 non-null     int64
#  4   user_name         70 non-null     object
#  5   user_screen_name  70 non-null     object
#  6   quote             70 non-null     int64
#  7   reply             70 non-null     int64
#  8   retweet           70 non-null     int64
#  9   favorite          70 non-null     int64
# dtypes: datetime64[ns, UTC](1), int64(6), object(3)
# memory usage: 8.1+ KB

# %% [markdown]
# ## Generamos el DataFrame de users para generar una tabla en SQL.

# %%
df_users=pd.DataFrame()

# %%
df_users['user_id']=db['user_id']
df_users['user_name']=db['user_id']
df_users['user_screen_name']=db['user_screen_name']
df_users.head()
# Out:
#                user_id            user_name user_screen_name
# 2  1099588676181471233  1099588676181471233        turoninos
# 3   763045308095950848   763045308095950848      Carlosevi94
# 4  1099588676181471233  1099588676181471233        turoninos
# 5              7154412              7154412         Recuenco
# 6           1003872445           1003872445       PauMugarra

# %%
df_users = df_users.drop_duplicates(['user_name'],keep='last')

# %%
df_users['user_name'].value_counts(ascending=True)
# Out:
# 763045308095950848     1
# 2227356042             1
# 1131933723681800193    1
# 41110484               1
# 210026854              1
# 1051649960             1
# 1073622740             1
# 1155468348139982848    1
# 2390191837             1
# 394734366              1
# 1327588137346998273    1
# 1398866593237508100    1
# 1533105519447404544    1
# 1641440478             1
# 1565028593629003777    1
# 1099588676181471233    1
# 1367036537943244803    1
# 1494355208473874438    1
# 2907682397             1
# 581925228              1
# 12085582               1
# 992943418052460544     1
# 7154412                1
# 1392422091434168323    1
# 1157259865389244417    1
# 2529499620             1
# 706520411551494145     1
# 21478536               1
# 917321990465351681     1
# 127000294              1
# 604485175              1
# 1391838162830385165    1
# 1127630178644054018    1
# 568101757              1
# 1262459681693409281    1
# 1393908772754575360    1
# 1252305008357527553    1
# 1003872445             1
# 975452621522853890     1
# 1311739853307027457    1
# 1162694149956603904    1
# Name: user_name, dtype: int64

# %%
df_users.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 41 entries, 3 to 69
# Data columns (total 3 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   user_id           41 non-null     int64
#  1   user_name         41 non-null     int64
#  2   user_screen_name  41 non-null     object
# dtypes: int64(2), object(1)
# memory usage: 1.3+ KB

# %% [markdown]
# ## Generamos otro Dataframe con los Tweets.
#
# Eliminamos los registros de _user_name_ y _user_screen_name_ del Dataframe, ya que se vincularán con la Tabla de users en SQL a través de una Query.

# %%
df_tweets=db.drop(columns=['user_name','user_screen_name'])
df_tweets.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 68 entries, 2 to 69
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   identity  68 non-null     int64
#  1   text      68 non-null     object
#  2   created   68 non-null     datetime64[ns, UTC]
#  3   user_id   68 non-null     int64
#  4   quote     68 non-null     int64
#  5   reply     68 non-null     int64
#  6   retweet   68 non-null     int64
#  7   favorite  68 non-null     int64
# dtypes: datetime64[ns, UTC](1), int64(6), object(1)
# memory usage: 4.8+ KB

# %%
df_tweets.head()
# Out:
#               identity                                               text  \
# 2  1577720804619571201  RT @TheBridge_Tech: Ya están aquí nuestros pri...
# 3  1577648996927012866  RT @TheBridge_Tech: ¡Feliz Día a nuestros Lead...
# 4  1577646040269864960  RT @TheBridge_Tech: ¡Feliz Día a nuestros Lead...
# 5  1577335173523308544  RT @PauMugarra: Recordaros que la semana que v...
# 6  1577334577701453827  Recordaros que la semana que viene tenemos la ...
#
#                     created              user_id  quote  reply  retweet  \
# 2 2022-10-05 18:02:07+00:00  1099588676181471233      0      0        0
# 3 2022-10-05 13:16:46+00:00   763045308095950848      0      0        0
# 4 2022-10-05 13:05:01+00:00  1099588676181471233      0      0        0
# 5 2022-10-04 16:29:45+00:00              7154412      0      0        0
# 6 2022-10-04 16:27:23+00:00           1003872445      0      0        2
#
#    favorite
# 2         0
# 3         0
# 4         0
# 5         0
# 6        12

# %% [markdown]
# ## Generamos las tablas de SQL.

# %%
connection = sqlite3.connect("Twitter_bridge.db")
crsr = connection.cursor()
res = crsr.execute("SELECT name FROM sqlite_master WHERE type='table'")
for name in res:
    print(name[0])
# Out:
# USERS
# TWEETS

# %%
query = '''
CREATE TABLE USERS (
    user_id INT NOT NULL,
    user_name VARCHAR(50) NOT NULL,
    user_screen_name VARCHAR(50) NOT NULL,
    PRIMARY KEY (user_id)   
);'''
crsr.execute(query)

# %%
query = '''
CREATE TABLE TWEETS (
    identity INT NOT NULL,
    text VARCHAR(250) NOT NULL,
    created DATE NOT NULL,
    user_id INT NOT NULL,
    quote INT, 
    reply INT,
    retweet INT,
    favorite INT,
	FOREIGN KEY (user_id) REFERENCES USERS(user_id),
    PRIMARY KEY (identity)   
);'''
crsr.execute(query)

# %% [markdown]
# #### Ingresamos los datos desde los DataFrames a las tablas generadas en SQL.

# %%
df_users.to_sql("USERS", connection, if_exists="replace")
# Out:
# 41

# %%
df_tweets.to_sql("TWEETS", connection, if_exists="replace")
# Out:
# 68

# %%
# ATENCIÓN! Al terminar hay que cerrar la conexión a la DB para que se guarden los cambios!!!!!!
connection.commit()
connection.close()
